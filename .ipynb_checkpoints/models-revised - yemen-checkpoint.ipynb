# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import CubicSpline

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from math import sqrt

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# Set seed 
SEED = 42

np.random.seed(SEED)              
torch.manual_seed(SEED)           
torch.cuda.manual_seed(SEED)     
torch.cuda.manual_seed_all(SEED)

# %%
# Load dataset
df = pd.read_csv('internet_usage.csv')
print("Shape of the Dataset: ", df.shape)
df.head()
# Out:
# Shape of the Dataset:  (217, 26)
#      Country Name Country Code      2000        2001       2002       2003  \
# 0     Afghanistan          AFG        ..  0.00472257  0.0045614  0.0878913
# 1         Albania          ALB  0.114097    0.325798   0.390081     0.9719
# 2         Algeria          DZA  0.491706    0.646114    1.59164    2.19536
# 3  American Samoa          ASM        ..          ..         ..         ..
# 4         Andorra          AND   10.5388          ..    11.2605    13.5464
#
#        2004     2005     2006     2007  ...  2014  2015     2016     2017  \
# 0  0.105809  1.22415  2.10712      1.9  ...     7  8.26       11     13.5
# 1   2.42039  6.04389  9.60999  15.0361  ...  54.3  56.9     59.6     62.4
# 2   4.63448  5.84394  7.37598  9.45119  ...  29.5  38.2  42.9455  47.6911
# 3        ..       ..       ..       ..  ...    ..    ..       ..       ..
# 4    26.838  37.6058  48.9368    70.87  ...  86.1  87.9     89.7  91.5675
#
#       2018     2019     2020     2021     2022     2023
# 0     16.8     17.6     18.4       ..       ..       ..
# 1     65.4  68.5504  72.2377  79.3237  82.6137  83.1356
# 2  49.0385  58.9776  60.6534  66.2356  71.2432       ..
# 3       ..       ..       ..       ..       ..       ..
# 4       ..  90.7187  93.2056  93.8975  94.4855       ..
#
# [5 rows x 26 columns]

# %%
# Take data for Germany
df_germany = df[df['Country Name'] == 'Germany']
df_germany
# Out:
#    Country Name Country Code     2000     2001   2002  2003   2004   2005  \
# 73      Germany          DEU  30.2163  31.6509  48.82  55.9  64.73  68.71
#
#      2006   2007  ...     2014     2015     2016     2017     2018     2019  \
# 73  72.16  75.16  ...  86.1937  87.5898  84.1652  84.3942  87.0371  88.1345
#
#        2020     2021     2022     2023
# 73  89.8129  91.4306  91.6298  92.4764
#
# [1 rows x 26 columns]

# %%
# Preprocess the dataset
df_germany = df_germany.drop(columns=['Country Code'])
df_germany_transposed = df_germany.T
df_germany_transposed = df_germany_transposed.reset_index()
df_germany_transposed.columns = ['Time', 'Penetration']
df_germany_transposed['Penetration'] = pd.to_numeric(df_germany_transposed['Penetration'], errors='coerce')
df_germany_transposed = df_germany_transposed.dropna()

# %%
# Plot internet penetration rate over years
plt.figure(figsize=(8, 5))
plt.plot(df_germany_transposed['Time'], df_germany_transposed['Penetration'], marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Penetration')
plt.title('Penetration Over Years')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("figures/penetration-over-years.png", bbox_inches='tight')
plt.show()

# %%
# Print Total number of datapoints before Interpolation
total_datapoints = len(df_germany_transposed)
print("Total number of datapoints before interpolation: ", total_datapoints)
# Out:
# Total number of datapoints before interpolation:  24

# %%
# Interpolate dataset to get weekly penetration rates (WITH NOISE)
df = df_germany_transposed.copy()
df['Time'] = pd.to_numeric(df['Time'], errors='coerce')
df['Penetration'] = pd.to_numeric(df['Penetration'], errors='coerce')

weekly_dates = pd.date_range(start=f"{int(df['Time'].min())}-01-01",
                             end=f"{int(df['Time'].max())}-12-31",
                             freq='7D')

weekly_years = weekly_dates.year + (weekly_dates.day_of_year - 1) / 365.25

cs = CubicSpline(df['Time'], df['Penetration'])
weekly_penetration = cs(weekly_years)

noise = np.random.normal(0, 0.1, size=len(weekly_penetration))
weekly_penetration_noisy = weekly_penetration + noise

df_weekly = pd.DataFrame({
    'Date': weekly_dates,
    'Penetration': weekly_penetration_noisy
})

print(len(df_weekly), "total points")
# Out:
# 1253 total points

# %%
#Plot Datapoints after interpolation ----------#
# Plot first 100 points
plt.figure(figsize=(8, 5))
plt.plot(df_weekly['Date'][:100], df_weekly['Penetration'][:100], marker='o', color='green')
plt.title("Internet Penetration - First 100 Points")
plt.xlabel("Date")
plt.ylabel("Penetration (%)")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig("figures/interpolated-penetration-first-100-points.png", bbox_inches='tight')
plt.show()

# Plot whole dataset
plt.figure(figsize=(8, 5))
plt.plot(df_weekly['Date'], df_weekly['Penetration'], marker='o', color='blue')
plt.title("Internet Penetration - Full Dataset")
plt.xlabel("Date")
plt.ylabel("Penetration (%)")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig("figures/interpolated-penetration-whole-dataset.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Deep Learning Model (Bi-LSTM)**

# %%
#Prepare Dataset for forecasting
class TimeSeriesDataset(Dataset):
    def __init__(self, data, seq_length=64):
        self.seq_length = seq_length
        self.series = data['Penetration'].values.astype(np.float32)

    def __len__(self):
        return len(self.series) - self.seq_length

    def __getitem__(self, idx):
        x = self.series[idx:idx+self.seq_length].reshape(-1, 1)
        y = self.series[idx + self.seq_length]
        return torch.tensor(x), torch.tensor(y)

# %%
#Define LSTM Model
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=2, dropout=0.3, bidirectional=True):
        super(LSTMModel, self).__init__()
        self.bidirectional = bidirectional
        self.lstm = nn.LSTM(
            input_size,
            hidden_size,
            num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )
        direction_factor = 2 if bidirectional else 1
        self.fc = nn.Linear(hidden_size * direction_factor, 1)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        out = self.dropout(out)
        out = self.fc(out)
        return out.squeeze(1)

# %%
#Preprocess data chronologically
df_weekly_lstm = df_weekly.sort_values('Date').reset_index(drop=True)

# %%
# Split dataset by time (first 80% train, last 20% test) 
dataset_size = len(df_weekly_lstm)
train_size = int(dataset_size * 0.8)

train_df = df_weekly_lstm.iloc[:train_size].reset_index(drop=True)
test_df = df_weekly_lstm.iloc[train_size:].reset_index(drop=True)

# %%
#Scale the target variable (only on train, then apply to test)
scaler_y = StandardScaler()
train_df['Penetration'] = scaler_y.fit_transform(train_df[['Penetration']])
test_df['Penetration'] = scaler_y.transform(test_df[['Penetration']])

# %%
#Create train and test dataset using TimeSeriesDataset
seq_length = 64
train_dataset = TimeSeriesDataset(train_df, seq_length=seq_length)
test_dataset = TimeSeriesDataset(test_df, seq_length=seq_length)

# --------- Create DataLoaders ---------
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
#Print total number of sequences in train set and test set
print("Number of sequences in training set: ", len(train_loader))
print("Number of sequences in test set ", len(test_loader))
# Out:
# Number of sequences in training set:  59
# Number of sequences in test set  12

# %%
# Initialize model, loss, optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMModel(input_size=1, hidden_size=64, num_layers=2).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Training loop

best_r2 = -np.inf
best_model_path = "best_lstm_model.pth"

train_losses = []
val_losses = []

epochs = 300
for epoch in range(epochs):
    model.train()
    total_train_loss = 0

    # Training
    for x_batch, y_batch in train_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        output = model(x_batch)
        loss = criterion(output, y_batch)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item() * x_batch.size(0)

    avg_train_loss = total_train_loss / len(train_loader.dataset)
    train_losses.append(avg_train_loss)

    #Validation
    model.eval()
    total_val_loss = 0
    y_true = []
    y_pred = []

    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            output = model(x_batch)
            loss = criterion(output, y_batch)
            total_val_loss += loss.item() * x_batch.size(0)

            y_true.extend(y_batch.cpu().numpy())
            y_pred.extend(output.cpu().numpy())

    avg_val_loss = total_val_loss / len(test_loader.dataset)
    val_losses.append(avg_val_loss)

    # Inverse transform to compute R2
    y_true_inv = scaler_y.inverse_transform(np.array(y_true).reshape(-1, 1)).flatten()
    y_pred_inv = scaler_y.inverse_transform(np.array(y_pred).reshape(-1, 1)).flatten()
    r2 = r2_score(y_true_inv, y_pred_inv)

    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {avg_train_loss:.6f} - Val Loss: {avg_val_loss:.6f} - R2: {r2:.4f}")

    # Save best model
    if r2 > best_r2:
        best_r2 = r2
        torch.save(model.state_dict(), best_model_path)
# Out:
# Epoch 1/300 - Train Loss: 0.371070 - Val Loss: 0.254146 - R2: -32.9235
# Epoch 2/300 - Train Loss: 0.145909 - Val Loss: 0.076226 - R2: -9.1747
# Epoch 3/300 - Train Loss: 0.121984 - Val Loss: 0.116807 - R2: -14.5915
# Epoch 4/300 - Train Loss: 0.331518 - Val Loss: 0.017385 - R2: -1.3206
# Epoch 5/300 - Train Loss: 0.112185 - Val Loss: 0.045422 - R2: -5.0630
# Epoch 6/300 - Train Loss: 0.064599 - Val Loss: 0.052096 - R2: -5.9538
# Epoch 7/300 - Train Loss: 0.024478 - Val Loss: 0.020908 - R2: -1.7909
# Epoch 8/300 - Train Loss: 0.054843 - Val Loss: 0.031811 - R2: -3.2462
# Epoch 9/300 - Train Loss: 0.035050 - Val Loss: 0.017169 - R2: -1.2918
# Epoch 10/300 - Train Loss: 0.068883 - Val Loss: 0.008975 - R2: -0.1979
# Epoch 11/300 - Train Loss: 0.036665 - Val Loss: 0.007485 - R2: 0.0008
# Epoch 12/300 - Train Loss: 0.048086 - Val Loss: 0.001854 - R2: 0.7525
# Epoch 13/300 - Train Loss: 0.027493 - Val Loss: 0.017864 - R2: -1.3845
# Epoch 14/300 - Train Loss: 0.041466 - Val Loss: 0.004607 - R2: 0.3850
# Epoch 15/300 - Train Loss: 0.025720 - Val Loss: 0.011223 - R2: -0.4981
# Epoch 16/300 - Train Loss: 0.037599 - Val Loss: 0.002906 - R2: 0.6121
# Epoch 17/300 - Train Loss: 0.024271 - Val Loss: 0.008133 - R2: -0.0856
# Epoch 18/300 - Train Loss: 0.040599 - Val Loss: 0.001699 - R2: 0.7732
# Epoch 19/300 - Train Loss: 0.025387 - Val Loss: 0.014909 - R2: -0.9900
# Epoch 20/300 - Train Loss: 0.039951 - Val Loss: 0.000577 - R2: 0.9230
# Epoch 21/300 - Train Loss: 0.024959 - Val Loss: 0.013462 - R2: -0.7969
# Epoch 22/300 - Train Loss: 0.039452 - Val Loss: 0.000685 - R2: 0.9086
# Epoch 23/300 - Train Loss: 0.019760 - Val Loss: 0.013345 - R2: -0.7814
# Epoch 24/300 - Train Loss: 0.031341 - Val Loss: 0.000851 - R2: 0.8864
# Epoch 25/300 - Train Loss: 0.021171 - Val Loss: 0.007707 - R2: -0.0287
# Epoch 26/300 - Train Loss: 0.030456 - Val Loss: 0.000916 - R2: 0.8778
# Epoch 27/300 - Train Loss: 0.023769 - Val Loss: 0.019962 - R2: -1.6646
# Epoch 28/300 - Train Loss: 0.036624 - Val Loss: 0.002094 - R2: 0.7205
# Epoch 29/300 - Train Loss: 0.025756 - Val Loss: 0.013403 - R2: -0.7890
# Epoch 30/300 - Train Loss: 0.041282 - Val Loss: 0.001098 - R2: 0.8534
# Epoch 31/300 - Train Loss: 0.024619 - Val Loss: 0.014133 - R2: -0.8865
# Epoch 32/300 - Train Loss: 0.035740 - Val Loss: 0.000491 - R2: 0.9345
# Epoch 33/300 - Train Loss: 0.022027 - Val Loss: 0.011582 - R2: -0.5459
# Epoch 34/300 - Train Loss: 0.034329 - Val Loss: 0.001399 - R2: 0.8133
# Epoch 35/300 - Train Loss: 0.020441 - Val Loss: 0.016409 - R2: -1.1903
# Epoch 36/300 - Train Loss: 0.026553 - Val Loss: 0.002882 - R2: 0.6154
# Epoch 37/300 - Train Loss: 0.018751 - Val Loss: 0.024671 - R2: -2.2931
# Epoch 38/300 - Train Loss: 0.027250 - Val Loss: 0.003001 - R2: 0.5995
# Epoch 39/300 - Train Loss: 0.020311 - Val Loss: 0.013093 - R2: -0.7476
# Epoch 40/300 - Train Loss: 0.031414 - Val Loss: 0.000193 - R2: 0.9742
# Epoch 41/300 - Train Loss: 0.020461 - Val Loss: 0.011027 - R2: -0.4719
# Epoch 42/300 - Train Loss: 0.032479 - Val Loss: 0.000193 - R2: 0.9742
# Epoch 43/300 - Train Loss: 0.019804 - Val Loss: 0.009430 - R2: -0.2587
# Epoch 44/300 - Train Loss: 0.033749 - Val Loss: 0.000200 - R2: 0.9733
# Epoch 45/300 - Train Loss: 0.020712 - Val Loss: 0.005660 - R2: 0.2444
# Epoch 46/300 - Train Loss: 0.028877 - Val Loss: 0.000301 - R2: 0.9598
# Epoch 47/300 - Train Loss: 0.019612 - Val Loss: 0.006820 - R2: 0.0897
# Epoch 48/300 - Train Loss: 0.031983 - Val Loss: 0.000445 - R2: 0.9407
# Epoch 49/300 - Train Loss: 0.019683 - Val Loss: 0.006762 - R2: 0.0974
# Epoch 50/300 - Train Loss: 0.031866 - Val Loss: 0.000070 - R2: 0.9907
# Epoch 51/300 - Train Loss: 0.022238 - Val Loss: 0.007860 - R2: -0.0492
# Epoch 52/300 - Train Loss: 0.031486 - Val Loss: 0.001740 - R2: 0.7677
# Epoch 53/300 - Train Loss: 0.020646 - Val Loss: 0.009728 - R2: -0.2985
# Epoch 54/300 - Train Loss: 0.029216 - Val Loss: 0.000059 - R2: 0.9921
# Epoch 55/300 - Train Loss: 0.020727 - Val Loss: 0.017047 - R2: -1.2754
# Epoch 56/300 - Train Loss: 0.028412 - Val Loss: 0.000112 - R2: 0.9851
# Epoch 57/300 - Train Loss: 0.020555 - Val Loss: 0.010416 - R2: -0.3903
# Epoch 58/300 - Train Loss: 0.027017 - Val Loss: 0.000389 - R2: 0.9480
# Epoch 59/300 - Train Loss: 0.018925 - Val Loss: 0.004616 - R2: 0.3838
# Epoch 60/300 - Train Loss: 0.027923 - Val Loss: 0.002652 - R2: 0.6461
# Epoch 61/300 - Train Loss: 0.016265 - Val Loss: 0.006028 - R2: 0.1953
# Epoch 62/300 - Train Loss: 0.022020 - Val Loss: 0.002179 - R2: 0.7091
# Epoch 63/300 - Train Loss: 0.015045 - Val Loss: 0.001294 - R2: 0.8273
# Epoch 64/300 - Train Loss: 0.021363 - Val Loss: 0.001661 - R2: 0.7783
# Epoch 65/300 - Train Loss: 0.018479 - Val Loss: 0.001275 - R2: 0.8298
# Epoch 66/300 - Train Loss: 0.028389 - Val Loss: 0.001372 - R2: 0.8168
# Epoch 67/300 - Train Loss: 0.021088 - Val Loss: 0.018421 - R2: -1.4588
# Epoch 68/300 - Train Loss: 0.030721 - Val Loss: 0.000668 - R2: 0.9109
# Epoch 69/300 - Train Loss: 0.024590 - Val Loss: 0.006064 - R2: 0.1906
# Epoch 70/300 - Train Loss: 0.038049 - Val Loss: 0.003905 - R2: 0.4788
# Epoch 71/300 - Train Loss: 0.022347 - Val Loss: 0.018311 - R2: -1.4441
# Epoch 72/300 - Train Loss: 0.033113 - Val Loss: 0.000224 - R2: 0.9701
# Epoch 73/300 - Train Loss: 0.020354 - Val Loss: 0.006242 - R2: 0.1668
# Epoch 74/300 - Train Loss: 0.029675 - Val Loss: 0.002851 - R2: 0.6195
# Epoch 75/300 - Train Loss: 0.017149 - Val Loss: 0.007517 - R2: -0.0034
# Epoch 76/300 - Train Loss: 0.025169 - Val Loss: 0.002201 - R2: 0.7062
# Epoch 77/300 - Train Loss: 0.015584 - Val Loss: 0.012942 - R2: -0.7275
# Epoch 78/300 - Train Loss: 0.017732 - Val Loss: 0.000239 - R2: 0.9682
# Epoch 79/300 - Train Loss: 0.015289 - Val Loss: 0.001033 - R2: 0.8621
# Epoch 80/300 - Train Loss: 0.022081 - Val Loss: 0.002941 - R2: 0.6075
# Epoch 81/300 - Train Loss: 0.014107 - Val Loss: 0.002059 - R2: 0.7251
# Epoch 82/300 - Train Loss: 0.020025 - Val Loss: 0.005467 - R2: 0.2703
# Epoch 83/300 - Train Loss: 0.015441 - Val Loss: 0.007598 - R2: -0.0142
# Epoch 84/300 - Train Loss: 0.025130 - Val Loss: 0.001231 - R2: 0.8356
# Epoch 85/300 - Train Loss: 0.019494 - Val Loss: 0.003356 - R2: 0.5520
# Epoch 86/300 - Train Loss: 0.029435 - Val Loss: 0.003632 - R2: 0.5152
# Epoch 87/300 - Train Loss: 0.018449 - Val Loss: 0.001049 - R2: 0.8600
# Epoch 88/300 - Train Loss: 0.024588 - Val Loss: 0.001589 - R2: 0.7879
# Epoch 89/300 - Train Loss: 0.015458 - Val Loss: 0.004243 - R2: 0.4337
# Epoch 90/300 - Train Loss: 0.018907 - Val Loss: 0.000896 - R2: 0.8803
# Epoch 91/300 - Train Loss: 0.012176 - Val Loss: 0.000510 - R2: 0.9319
# Epoch 92/300 - Train Loss: 0.018484 - Val Loss: 0.001520 - R2: 0.7971
# Epoch 93/300 - Train Loss: 0.010941 - Val Loss: 0.000426 - R2: 0.9431
# Epoch 94/300 - Train Loss: 0.015616 - Val Loss: 0.001942 - R2: 0.7408
# Epoch 95/300 - Train Loss: 0.011082 - Val Loss: 0.000223 - R2: 0.9703
# Epoch 96/300 - Train Loss: 0.013576 - Val Loss: 0.000538 - R2: 0.9282
# Epoch 97/300 - Train Loss: 0.012033 - Val Loss: 0.000295 - R2: 0.9606
# Epoch 98/300 - Train Loss: 0.021239 - Val Loss: 0.001375 - R2: 0.8164
# Epoch 99/300 - Train Loss: 0.014388 - Val Loss: 0.006753 - R2: 0.0986
# Epoch 100/300 - Train Loss: 0.020409 - Val Loss: 0.000567 - R2: 0.9244
# Epoch 101/300 - Train Loss: 0.018764 - Val Loss: 0.004243 - R2: 0.4336
# Epoch 102/300 - Train Loss: 0.031860 - Val Loss: 0.001478 - R2: 0.8027
# Epoch 103/300 - Train Loss: 0.019540 - Val Loss: 0.000348 - R2: 0.9536
# Epoch 104/300 - Train Loss: 0.028915 - Val Loss: 0.001537 - R2: 0.7948
# Epoch 105/300 - Train Loss: 0.015427 - Val Loss: 0.004180 - R2: 0.4421
# Epoch 106/300 - Train Loss: 0.022889 - Val Loss: 0.000832 - R2: 0.8889
# Epoch 107/300 - Train Loss: 0.015292 - Val Loss: 0.002495 - R2: 0.6670
# Epoch 108/300 - Train Loss: 0.024773 - Val Loss: 0.000379 - R2: 0.9494
# Epoch 109/300 - Train Loss: 0.017920 - Val Loss: 0.003477 - R2: 0.5359
# Epoch 110/300 - Train Loss: 0.031443 - Val Loss: 0.002598 - R2: 0.6532
# Epoch 111/300 - Train Loss: 0.015259 - Val Loss: 0.005473 - R2: 0.2694
# Epoch 112/300 - Train Loss: 0.023489 - Val Loss: 0.002108 - R2: 0.7187
# Epoch 113/300 - Train Loss: 0.016064 - Val Loss: 0.008821 - R2: -0.1775
# Epoch 114/300 - Train Loss: 0.022242 - Val Loss: 0.000503 - R2: 0.9328
# Epoch 115/300 - Train Loss: 0.015057 - Val Loss: 0.000491 - R2: 0.9344
# Epoch 116/300 - Train Loss: 0.023969 - Val Loss: 0.000069 - R2: 0.9908
# Epoch 117/300 - Train Loss: 0.013557 - Val Loss: 0.008386 - R2: -0.1193
# Epoch 118/300 - Train Loss: 0.019609 - Val Loss: 0.001850 - R2: 0.7531
# Epoch 119/300 - Train Loss: 0.015255 - Val Loss: 0.008963 - R2: -0.1964
# Epoch 120/300 - Train Loss: 0.022843 - Val Loss: 0.000168 - R2: 0.9776
# Epoch 121/300 - Train Loss: 0.015941 - Val Loss: 0.000374 - R2: 0.9501
# Epoch 122/300 - Train Loss: 0.021081 - Val Loss: 0.002428 - R2: 0.6758
# Epoch 123/300 - Train Loss: 0.013095 - Val Loss: 0.001242 - R2: 0.8343
# Epoch 124/300 - Train Loss: 0.017523 - Val Loss: 0.003980 - R2: 0.4688
# Epoch 125/300 - Train Loss: 0.012718 - Val Loss: 0.000173 - R2: 0.9770
# Epoch 126/300 - Train Loss: 0.018563 - Val Loss: 0.000571 - R2: 0.9238
# Epoch 127/300 - Train Loss: 0.012558 - Val Loss: 0.002278 - R2: 0.6960
# Epoch 128/300 - Train Loss: 0.016093 - Val Loss: 0.000377 - R2: 0.9497
# Epoch 129/300 - Train Loss: 0.014113 - Val Loss: 0.000151 - R2: 0.9798
# Epoch 130/300 - Train Loss: 0.019911 - Val Loss: 0.000105 - R2: 0.9860
# Epoch 131/300 - Train Loss: 0.011595 - Val Loss: 0.004343 - R2: 0.4202
# Epoch 132/300 - Train Loss: 0.018861 - Val Loss: 0.001204 - R2: 0.8393
# Epoch 133/300 - Train Loss: 0.014816 - Val Loss: 0.002190 - R2: 0.7077
# Epoch 134/300 - Train Loss: 0.023279 - Val Loss: 0.000157 - R2: 0.9790
# Epoch 135/300 - Train Loss: 0.017667 - Val Loss: 0.001903 - R2: 0.7460
# Epoch 136/300 - Train Loss: 0.027151 - Val Loss: 0.000636 - R2: 0.9151
# Epoch 137/300 - Train Loss: 0.016421 - Val Loss: 0.002021 - R2: 0.7302
# Epoch 138/300 - Train Loss: 0.024707 - Val Loss: 0.000542 - R2: 0.9277
# Epoch 139/300 - Train Loss: 0.014436 - Val Loss: 0.005475 - R2: 0.2692
# Epoch 140/300 - Train Loss: 0.021836 - Val Loss: 0.000066 - R2: 0.9912
# Epoch 141/300 - Train Loss: 0.014720 - Val Loss: 0.002534 - R2: 0.6617
# Epoch 142/300 - Train Loss: 0.020394 - Val Loss: 0.001107 - R2: 0.8523
# Epoch 143/300 - Train Loss: 0.014223 - Val Loss: 0.000860 - R2: 0.8853
# Epoch 144/300 - Train Loss: 0.017264 - Val Loss: 0.007765 - R2: -0.0365
# Epoch 145/300 - Train Loss: 0.012456 - Val Loss: 0.000601 - R2: 0.9198
# Epoch 146/300 - Train Loss: 0.017056 - Val Loss: 0.000740 - R2: 0.9013
# Epoch 147/300 - Train Loss: 0.010121 - Val Loss: 0.004168 - R2: 0.4437
# Epoch 148/300 - Train Loss: 0.016944 - Val Loss: 0.000704 - R2: 0.9061
# Epoch 149/300 - Train Loss: 0.015527 - Val Loss: 0.002925 - R2: 0.6095
# Epoch 150/300 - Train Loss: 0.024586 - Val Loss: 0.000226 - R2: 0.9698
# Epoch 151/300 - Train Loss: 0.016025 - Val Loss: 0.000576 - R2: 0.9231
# Epoch 152/300 - Train Loss: 0.019767 - Val Loss: 0.002508 - R2: 0.6652
# Epoch 153/300 - Train Loss: 0.012169 - Val Loss: 0.000073 - R2: 0.9902
# Epoch 154/300 - Train Loss: 0.015263 - Val Loss: 0.005757 - R2: 0.2315
# Epoch 155/300 - Train Loss: 0.012075 - Val Loss: 0.000188 - R2: 0.9749
# Epoch 156/300 - Train Loss: 0.017451 - Val Loss: 0.000541 - R2: 0.9277
# Epoch 157/300 - Train Loss: 0.014727 - Val Loss: 0.000803 - R2: 0.8929
# Epoch 158/300 - Train Loss: 0.019332 - Val Loss: 0.006002 - R2: 0.1989
# Epoch 159/300 - Train Loss: 0.017714 - Val Loss: 0.000996 - R2: 0.8670
# Epoch 160/300 - Train Loss: 0.025129 - Val Loss: 0.008502 - R2: -0.1348
# Epoch 161/300 - Train Loss: 0.013936 - Val Loss: 0.000235 - R2: 0.9686
# Epoch 162/300 - Train Loss: 0.020499 - Val Loss: 0.006920 - R2: 0.0763
# Epoch 163/300 - Train Loss: 0.011600 - Val Loss: 0.002089 - R2: 0.7212
# Epoch 164/300 - Train Loss: 0.014562 - Val Loss: 0.006836 - R2: 0.0875
# Epoch 165/300 - Train Loss: 0.011131 - Val Loss: 0.000415 - R2: 0.9446
# Epoch 166/300 - Train Loss: 0.012559 - Val Loss: 0.001636 - R2: 0.7817
# Epoch 167/300 - Train Loss: 0.010708 - Val Loss: 0.000684 - R2: 0.9087
# Epoch 168/300 - Train Loss: 0.014256 - Val Loss: 0.004809 - R2: 0.3580
# Epoch 169/300 - Train Loss: 0.010527 - Val Loss: 0.000592 - R2: 0.9210
# Epoch 170/300 - Train Loss: 0.015453 - Val Loss: 0.000829 - R2: 0.8894
# Epoch 171/300 - Train Loss: 0.012138 - Val Loss: 0.000253 - R2: 0.9662
# Epoch 172/300 - Train Loss: 0.016703 - Val Loss: 0.006234 - R2: 0.1678
# Epoch 173/300 - Train Loss: 0.013250 - Val Loss: 0.000591 - R2: 0.9211
# Epoch 174/300 - Train Loss: 0.017672 - Val Loss: 0.003895 - R2: 0.4801
# Epoch 175/300 - Train Loss: 0.013672 - Val Loss: 0.000771 - R2: 0.8971
# Epoch 176/300 - Train Loss: 0.023091 - Val Loss: 0.002765 - R2: 0.6309
# Epoch 177/300 - Train Loss: 0.015193 - Val Loss: 0.000207 - R2: 0.9724
# Epoch 178/300 - Train Loss: 0.020054 - Val Loss: 0.018405 - R2: -1.4567
# Epoch 179/300 - Train Loss: 0.013352 - Val Loss: 0.001493 - R2: 0.8007
# Epoch 180/300 - Train Loss: 0.015743 - Val Loss: 0.008621 - R2: -0.1508
# Epoch 181/300 - Train Loss: 0.011105 - Val Loss: 0.000538 - R2: 0.9281
# Epoch 182/300 - Train Loss: 0.016617 - Val Loss: 0.000214 - R2: 0.9715
# Epoch 183/300 - Train Loss: 0.010565 - Val Loss: 0.000431 - R2: 0.9424
# Epoch 184/300 - Train Loss: 0.013505 - Val Loss: 0.011210 - R2: -0.4964
# Epoch 185/300 - Train Loss: 0.010913 - Val Loss: 0.000091 - R2: 0.9879
# Epoch 186/300 - Train Loss: 0.015476 - Val Loss: 0.002435 - R2: 0.6749
# Epoch 187/300 - Train Loss: 0.010987 - Val Loss: 0.003740 - R2: 0.5008
# Epoch 188/300 - Train Loss: 0.014075 - Val Loss: 0.000344 - R2: 0.9541
# Epoch 189/300 - Train Loss: 0.009436 - Val Loss: 0.000423 - R2: 0.9436
# Epoch 190/300 - Train Loss: 0.013508 - Val Loss: 0.001421 - R2: 0.8103
# Epoch 191/300 - Train Loss: 0.009796 - Val Loss: 0.000194 - R2: 0.9741
# Epoch 192/300 - Train Loss: 0.012262 - Val Loss: 0.011281 - R2: -0.5058
# Epoch 193/300 - Train Loss: 0.012040 - Val Loss: 0.000925 - R2: 0.8765
# Epoch 194/300 - Train Loss: 0.018221 - Val Loss: 0.009869 - R2: -0.3173
# Epoch 195/300 - Train Loss: 0.015725 - Val Loss: 0.000429 - R2: 0.9428
# Epoch 196/300 - Train Loss: 0.023762 - Val Loss: 0.020616 - R2: -1.7518
# Epoch 197/300 - Train Loss: 0.015399 - Val Loss: 0.002676 - R2: 0.6428
# Epoch 198/300 - Train Loss: 0.020814 - Val Loss: 0.003065 - R2: 0.5909
# Epoch 199/300 - Train Loss: 0.014319 - Val Loss: 0.000301 - R2: 0.9599
# Epoch 200/300 - Train Loss: 0.018049 - Val Loss: 0.003152 - R2: 0.5792
# Epoch 201/300 - Train Loss: 0.012499 - Val Loss: 0.000206 - R2: 0.9725
# Epoch 202/300 - Train Loss: 0.017352 - Val Loss: 0.008862 - R2: -0.1829
# Epoch 203/300 - Train Loss: 0.014387 - Val Loss: 0.001462 - R2: 0.8048
# Epoch 204/300 - Train Loss: 0.019233 - Val Loss: 0.009650 - R2: -0.2881
# Epoch 205/300 - Train Loss: 0.009812 - Val Loss: 0.009390 - R2: -0.2534
# Epoch 206/300 - Train Loss: 0.012904 - Val Loss: 0.020938 - R2: -1.7948
# Epoch 207/300 - Train Loss: 0.008241 - Val Loss: 0.002378 - R2: 0.6825
# Epoch 208/300 - Train Loss: 0.010804 - Val Loss: 0.011501 - R2: -0.5351
# Epoch 209/300 - Train Loss: 0.008934 - Val Loss: 0.006641 - R2: 0.1136
# Epoch 210/300 - Train Loss: 0.013914 - Val Loss: 0.005659 - R2: 0.2446
# Epoch 211/300 - Train Loss: 0.009400 - Val Loss: 0.002465 - R2: 0.6710
# Epoch 212/300 - Train Loss: 0.013617 - Val Loss: 0.004351 - R2: 0.4193
# Epoch 213/300 - Train Loss: 0.010548 - Val Loss: 0.000904 - R2: 0.8793
# Epoch 214/300 - Train Loss: 0.011593 - Val Loss: 0.020902 - R2: -1.7900
# Epoch 215/300 - Train Loss: 0.011071 - Val Loss: 0.001638 - R2: 0.7814
# Epoch 216/300 - Train Loss: 0.013142 - Val Loss: 0.004280 - R2: 0.4287
# Epoch 217/300 - Train Loss: 0.009220 - Val Loss: 0.000598 - R2: 0.9201
# Epoch 218/300 - Train Loss: 0.012887 - Val Loss: 0.008749 - R2: -0.1678
# Epoch 219/300 - Train Loss: 0.012211 - Val Loss: 0.000973 - R2: 0.8701
# Epoch 220/300 - Train Loss: 0.019932 - Val Loss: 0.011471 - R2: -0.5312
# Epoch 221/300 - Train Loss: 0.014696 - Val Loss: 0.000232 - R2: 0.9690
# Epoch 222/300 - Train Loss: 0.021608 - Val Loss: 0.008517 - R2: -0.1368
# Epoch 223/300 - Train Loss: 0.016034 - Val Loss: 0.000254 - R2: 0.9661
# Epoch 224/300 - Train Loss: 0.023148 - Val Loss: 0.004968 - R2: 0.3369
# Epoch 225/300 - Train Loss: 0.016888 - Val Loss: 0.000082 - R2: 0.9891
# Epoch 226/300 - Train Loss: 0.021719 - Val Loss: 0.010873 - R2: -0.4514
# Epoch 227/300 - Train Loss: 0.015195 - Val Loss: 0.000190 - R2: 0.9746
# Epoch 228/300 - Train Loss: 0.020032 - Val Loss: 0.012001 - R2: -0.6020
# Epoch 229/300 - Train Loss: 0.012444 - Val Loss: 0.003915 - R2: 0.4774
# Epoch 230/300 - Train Loss: 0.015388 - Val Loss: 0.012299 - R2: -0.6417
# Epoch 231/300 - Train Loss: 0.011076 - Val Loss: 0.006638 - R2: 0.1140
# Epoch 232/300 - Train Loss: 0.011614 - Val Loss: 0.014602 - R2: -0.9491
# Epoch 233/300 - Train Loss: 0.009579 - Val Loss: 0.000406 - R2: 0.9458
# Epoch 234/300 - Train Loss: 0.014291 - Val Loss: 0.006268 - R2: 0.1633
# Epoch 235/300 - Train Loss: 0.008650 - Val Loss: 0.009416 - R2: -0.2568
# Epoch 236/300 - Train Loss: 0.011939 - Val Loss: 0.002097 - R2: 0.7201
# Epoch 237/300 - Train Loss: 0.008281 - Val Loss: 0.008641 - R2: -0.1534
# Epoch 238/300 - Train Loss: 0.010047 - Val Loss: 0.002079 - R2: 0.7224
# Epoch 239/300 - Train Loss: 0.007522 - Val Loss: 0.004330 - R2: 0.4220
# Epoch 240/300 - Train Loss: 0.008562 - Val Loss: 0.007459 - R2: 0.0044
# Epoch 241/300 - Train Loss: 0.007046 - Val Loss: 0.000607 - R2: 0.9190
# Epoch 242/300 - Train Loss: 0.007779 - Val Loss: 0.005960 - R2: 0.2045
# Epoch 243/300 - Train Loss: 0.008114 - Val Loss: 0.011371 - R2: -0.5177
# Epoch 244/300 - Train Loss: 0.014055 - Val Loss: 0.000358 - R2: 0.9522
# Epoch 245/300 - Train Loss: 0.010981 - Val Loss: 0.009558 - R2: -0.2758
# Epoch 246/300 - Train Loss: 0.014968 - Val Loss: 0.007347 - R2: 0.0193
# Epoch 247/300 - Train Loss: 0.017411 - Val Loss: 0.007377 - R2: 0.0153
# Epoch 248/300 - Train Loss: 0.028881 - Val Loss: 0.003201 - R2: 0.5728
# Epoch 249/300 - Train Loss: 0.018093 - Val Loss: 0.001686 - R2: 0.7750
# Epoch 250/300 - Train Loss: 0.025689 - Val Loss: 0.000920 - R2: 0.8771
# Epoch 251/300 - Train Loss: 0.011969 - Val Loss: 0.000160 - R2: 0.9786
# Epoch 252/300 - Train Loss: 0.012939 - Val Loss: 0.005995 - R2: 0.1998
# Epoch 253/300 - Train Loss: 0.009923 - Val Loss: 0.002564 - R2: 0.6577
# Epoch 254/300 - Train Loss: 0.014118 - Val Loss: 0.002672 - R2: 0.6433
# Epoch 255/300 - Train Loss: 0.010863 - Val Loss: 0.000648 - R2: 0.9135
# Epoch 256/300 - Train Loss: 0.011828 - Val Loss: 0.000365 - R2: 0.9512
# Epoch 257/300 - Train Loss: 0.007668 - Val Loss: 0.002899 - R2: 0.6130
# Epoch 258/300 - Train Loss: 0.008675 - Val Loss: 0.010322 - R2: -0.3778
# Epoch 259/300 - Train Loss: 0.007095 - Val Loss: 0.002686 - R2: 0.6415
# Epoch 260/300 - Train Loss: 0.009525 - Val Loss: 0.012560 - R2: -0.6765
# Epoch 261/300 - Train Loss: 0.008712 - Val Loss: 0.000136 - R2: 0.9819
# Epoch 262/300 - Train Loss: 0.010875 - Val Loss: 0.006485 - R2: 0.1344
# Epoch 263/300 - Train Loss: 0.009045 - Val Loss: 0.000310 - R2: 0.9586
# Epoch 264/300 - Train Loss: 0.013072 - Val Loss: 0.004722 - R2: 0.3697
# Epoch 265/300 - Train Loss: 0.011238 - Val Loss: 0.000269 - R2: 0.9641
# Epoch 266/300 - Train Loss: 0.019174 - Val Loss: 0.008948 - R2: -0.1944
# Epoch 267/300 - Train Loss: 0.016943 - Val Loss: 0.003040 - R2: 0.5942
# Epoch 268/300 - Train Loss: 0.026251 - Val Loss: 0.014375 - R2: -0.9188
# Epoch 269/300 - Train Loss: 0.018012 - Val Loss: 0.001297 - R2: 0.8269
# Epoch 270/300 - Train Loss: 0.024585 - Val Loss: 0.007049 - R2: 0.0591
# Epoch 271/300 - Train Loss: 0.012554 - Val Loss: 0.000115 - R2: 0.9846
# Epoch 272/300 - Train Loss: 0.011171 - Val Loss: 0.003694 - R2: 0.5069
# Epoch 273/300 - Train Loss: 0.009028 - Val Loss: 0.000506 - R2: 0.9324
# Epoch 274/300 - Train Loss: 0.011171 - Val Loss: 0.004974 - R2: 0.3360
# Epoch 275/300 - Train Loss: 0.008675 - Val Loss: 0.000129 - R2: 0.9828
# Epoch 276/300 - Train Loss: 0.009827 - Val Loss: 0.002662 - R2: 0.6447
# Epoch 277/300 - Train Loss: 0.006866 - Val Loss: 0.002610 - R2: 0.6517
# Epoch 278/300 - Train Loss: 0.007490 - Val Loss: 0.003854 - R2: 0.4856
# Epoch 279/300 - Train Loss: 0.007912 - Val Loss: 0.006014 - R2: 0.1972
# Epoch 280/300 - Train Loss: 0.013891 - Val Loss: 0.000591 - R2: 0.9212
# Epoch 281/300 - Train Loss: 0.013120 - Val Loss: 0.002311 - R2: 0.6915
# Epoch 282/300 - Train Loss: 0.018082 - Val Loss: 0.006815 - R2: 0.0903
# Epoch 283/300 - Train Loss: 0.011691 - Val Loss: 0.003974 - R2: 0.4695
# Epoch 284/300 - Train Loss: 0.015507 - Val Loss: 0.005381 - R2: 0.2818
# Epoch 285/300 - Train Loss: 0.010626 - Val Loss: 0.000215 - R2: 0.9713
# Epoch 286/300 - Train Loss: 0.012142 - Val Loss: 0.003888 - R2: 0.4811
# Epoch 287/300 - Train Loss: 0.010867 - Val Loss: 0.000896 - R2: 0.8804
# Epoch 288/300 - Train Loss: 0.014490 - Val Loss: 0.004038 - R2: 0.4610
# Epoch 289/300 - Train Loss: 0.009749 - Val Loss: 0.001551 - R2: 0.7930
# Epoch 290/300 - Train Loss: 0.011914 - Val Loss: 0.012991 - R2: -0.7340
# Epoch 291/300 - Train Loss: 0.009070 - Val Loss: 0.003595 - R2: 0.5201
# Epoch 292/300 - Train Loss: 0.012956 - Val Loss: 0.014500 - R2: -0.9354
# Epoch 293/300 - Train Loss: 0.008180 - Val Loss: 0.000196 - R2: 0.9739
# Epoch 294/300 - Train Loss: 0.010270 - Val Loss: 0.005160 - R2: 0.3113
# Epoch 295/300 - Train Loss: 0.009823 - Val Loss: 0.000476 - R2: 0.9365
# Epoch 296/300 - Train Loss: 0.012996 - Val Loss: 0.002945 - R2: 0.6069
# Epoch 297/300 - Train Loss: 0.009076 - Val Loss: 0.000118 - R2: 0.9843
# Epoch 298/300 - Train Loss: 0.009083 - Val Loss: 0.010707 - R2: -0.4291
# Epoch 299/300 - Train Loss: 0.010294 - Val Loss: 0.000550 - R2: 0.9266
# Epoch 300/300 - Train Loss: 0.016305 - Val Loss: 0.008597 - R2: -0.1475

# %%
# Plot loss curve for lstm
plt.figure(figsize=(8, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid(True)
plt.savefig("figures/lstm-loss-curve.png", bbox_inches='tight')
plt.show()

# %%
# Evaluate LSTM model after training

best_model = LSTMModel(input_size=1, hidden_size=64, num_layers=2).to(device)
best_model.load_state_dict(torch.load(best_model_path))
best_model.to(device)
best_model.eval()

y_true_test, y_pred_test = [], []
with torch.no_grad():
    for x_batch, y_batch in test_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        output = best_model(x_batch)
        y_true_test.extend(y_batch.cpu().numpy())
        y_pred_test.extend(output.cpu().numpy())

y_true_test_inv = scaler_y.inverse_transform(np.array(y_true_test).reshape(-1, 1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(np.array(y_pred_test).reshape(-1, 1)).flatten()

lstm_rmse = np.sqrt(mean_squared_error(y_true_test_inv, y_pred_test_inv))
lstm_mae  = mean_absolute_error(y_true_test_inv, y_pred_test_inv)
lstm_mape = mean_absolute_percentage_error(y_true_test_inv, y_pred_test_inv)
lstm_r2   = r2_score(y_true_test_inv, y_pred_test_inv)

print(f"LSTM RMSE: {lstm_rmse:.4f}")
print(f"LSTM MAE : {lstm_mae:.4f}")
print(f"LSTM MAPE: {lstm_mape:.4f}")
print(f"LSTM R2  : {lstm_r2:.4f}")
# Out:
# LSTM RMSE: 0.1264
# LSTM MAE : 0.0973
# LSTM MAPE: 0.0011
# LSTM R2  : 0.9921

# %%
# Plot Real vs Predicted
plt.figure(figsize=(8,5))
plt.plot(y_true_test_inv, label="Real", color="blue")
plt.plot(y_pred_test_inv, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.grid(alpha=0.3)
plt.savefig("figures/real-vs-predicted-test-set-lstm.png", bbox_inches='tight')
plt.show()

def get_predictions(dataloader, model):
    preds, trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(device)
            output = model(x_batch)
            preds.extend(output.cpu().numpy())
            trues.extend(y_batch.cpu().numpy())
    return np.array(trues), np.array(preds)

y_true_train, y_pred_train = get_predictions(train_loader, best_model)
y_true_train = scaler_y.inverse_transform(y_true_train.reshape(-1, 1)).flatten()
y_pred_train = scaler_y.inverse_transform(y_pred_train.reshape(-1, 1)).flatten()

y_true_all = np.concatenate([y_true_train, y_true_test_inv])
y_pred_all = np.concatenate([y_pred_train, y_pred_test_inv])

plt.figure(figsize=(8,5))
plt.plot(range(len(y_true_all)), y_true_all, label="Real", color="blue")
plt.plot(range(len(y_pred_all)), y_pred_all, label="Predicted", color="red", linestyle="--")
plt.axvline(x=len(y_true_train), color="black", linestyle=":", label="Train/Test Split")
plt.title("Real vs Predicted - Whole Dataset (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.grid(alpha=0.3)
plt.savefig("figures/real-vs-predicted-whole-dataset-lstm.png", bbox_inches='tight')
plt.show()

# %%
# Plot residual plot and distribution of residual plot for lstm model

y_true_test = np.array(y_true_test)
y_pred_test = np.array(y_pred_test)
residuals_test = y_true_test - y_pred_test

# Residual Plot
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-lstm.png", bbox_inches='tight')
plt.show()

#Distribution of Residuals
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, kde=True, bins=30, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution (LSTM)")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distributions-lstm.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Machine Learning Model 1: Random Forest**

# %%
# Prepare dataset for Random Forest

df_weekly = df_weekly.sort_values('Date').reset_index(drop=True)
series = df_weekly['Penetration'].values

def create_features(series, seq_length=64):
    X, y = [], []
    for i in range(seq_length, len(series)):
        lag_window = series[i-seq_length:i].copy()
        diff_window = np.diff(lag_window, prepend=lag_window[0])
        feature_row = np.concatenate([lag_window, diff_window])
        X.append(feature_row)
        y.append(series[i])
    return np.array(X), np.array(y)

seq_length = 64
X, y = create_features(series, seq_length)

time_index = np.arange(len(series))[seq_length:].reshape(-1,1)
X = np.hstack([X, time_index])

# Train/test split (first 80% train, last 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Scale features
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1,1)).flatten()
y_test_scaled = scaler_y.transform(y_test.reshape(-1,1)).flatten()

# %%
# Train Random Forest
rf_model = RandomForestRegressor(n_estimators=300, max_depth=15, random_state=42)
rf_model.fit(X_train_scaled, y_train_scaled)
# Out:
# RandomForestRegressor(max_depth=15, n_estimators=300, random_state=42)

# %%
# Predictions
y_pred_train_scaled = rf_model.predict(X_train_scaled)
y_pred_test_scaled = rf_model.predict(X_test_scaled)

y_pred_train = scaler_y.inverse_transform(y_pred_train_scaled.reshape(-1,1)).flatten()
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled.reshape(-1,1)).flatten()

# Metrics
rf_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
rf_mae  = mean_absolute_error(y_test, y_pred_test)
rf_mape = mean_absolute_percentage_error(y_test, y_pred_test)
rf_r2   = r2_score(y_test, y_pred_test)

print(f"Random Forest RMSE: {rf_rmse:.4f}")
print(f"Random Forest MAE : {rf_mae:.4f}")
print(f"Random Forest MAPE: {rf_mape:.4f}")
print(f"Random Forest R2  : {rf_r2:.4f}")
# Out:
# Random Forest RMSE: 3.4514
# Random Forest MAE : 3.0129
# Random Forest MAPE: 0.0325
# Random Forest R2  : -3.1942

# %%
#Real vs Predicted (Test Set) 
plt.figure(figsize=(8,5))
plt.plot(y_test, label="Real", color="blue")
plt.plot(y_pred_test, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (Random Forest)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-test-set-rf.png", bbox_inches='tight')
plt.show()

#Real vs Predicted (Whole Dataset)
y_true_all = np.concatenate([y_train, y_test])
y_pred_all = np.concatenate([y_pred_train, y_pred_test])

plt.figure(figsize=(8,5))
plt.plot(range(len(y_true_all)), y_true_all, label="Real", color="blue")
plt.plot(range(len(y_pred_all)), y_pred_all, label="Predicted", color="red", linestyle="--")
plt.axvline(x=len(y_train), color="black", linestyle=":", label="Train/Test Split")
plt.title("Real vs Predicted - Whole Dataset (Random Forest)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-whole-dataset-rf.png", bbox_inches='tight')
plt.show()

# %%
#Residual Plot (Test Set)
residuals_test = y_test - y_pred_test
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot (Random Forest)")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-rf.png", bbox_inches='tight')
plt.show()

#Residual Distribution (Test Set)
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, kde=True, bins=30, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution (Random Forest)")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distributions-rf.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Machine Learning Model 2: SARIMAX**

# %%
#Prepare series
df_weekly = df_weekly.sort_values('Date').reset_index(drop=True)
series = df_weekly['Penetration']

#Train/Test Split
train_size = int(len(series) * 0.8)
train_series = series[:train_size]
test_series = series[train_size:]

# %%
# Fit SARIMAX model

sarimax_model = SARIMAX(
    train_series, 
    order=(1,1,1), 
    seasonal_order=(1,1,1,52),
    enforce_stationarity=False,
    enforce_invertibility=False
)
sarimax_result = sarimax_model.fit(disp=False)

# %%
# --------- Predictions ---------
train_pred = sarimax_result.predict(start=0, end=len(train_series)-1, dynamic=False)

# Forecast test
test_pred = sarimax_result.forecast(steps=len(test_series))

# --------- Metrics ---------
sarimax_rmse = np.sqrt(mean_squared_error(test_series, test_pred))
sarimax_mae  = mean_absolute_error(test_series, test_pred)
sarimax_mape = mean_absolute_percentage_error(test_series, test_pred)
sarimax_r2   = r2_score(test_series, test_pred)

print(f"SARIMAX RMSE: {sarimax_rmse:.4f}")
print(f"SARIMAX MAE : {sarimax_mae:.4f}")
print(f"SARIMAX MAPE: {sarimax_mape:.4f}")
print(f"SARIMAX R2  : {sarimax_r2:.4f}")
# Out:
# SARIMAX RMSE: 0.6875
# SARIMAX MAE : 0.5509
# SARIMAX MAPE: 0.0060
# SARIMAX R2  : 0.8516

# %%
#Plot Test Set(Actual vs Predicted) 
plt.figure(figsize=(8,5))
plt.plot(test_series.values, label="Real", color="blue")
plt.plot(test_pred.values, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (SARIMAX)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-test-set-sarimax.png", bbox_inches='tight')

plt.show()

# --------- Plot Whole Series ---------
all_real = np.concatenate([train_series.values, test_series.values])
all_pred = np.concatenate([train_pred.values, test_pred.values])

plt.figure(figsize=(8,5))
plt.plot(range(len(all_real)), all_real, label="Real", color="blue")
plt.plot(range(len(all_pred)), all_pred, label="Predicted", color="red", linestyle="--")
plt.axvline(x=len(train_series), color="black", linestyle=":", label="Train/Test Split")
plt.title("Real vs Predicted - Whole Datast (SARIMAX)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-whole-dataset-sarimax.png", bbox_inches='tight')
plt.show()

# %%
#Residual Plot
residuals_test = test_series.values - test_pred.values
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot SARIMAX")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-sarimax.png", bbox_inches='tight')
plt.show()

#Residual Distribution
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, bins=30, kde=True, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution SARIMAX")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distribution-sarimax.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Comparison of All three models**

# %%
#Metrics for each model
data = {
    "Model": ["LSTM", "SARIMAX", "Random Forest"],
    "Type":  ["Deep Learning", "Machine Learning", "Machine Learning"],
    "RMSE":  [lstm_rmse, sarimax_rmse, rf_rmse],
    "MAE":   [lstm_mae, sarimax_mae, rf_mae],
    "MAPE":  [lstm_mape, sarimax_mape, rf_mape],
    "R2":    [lstm_r2, sarimax_r2, rf_r2]
}

df_metrics = pd.DataFrame(data)

#Display the table
print("Comparison of Models:")
df_metrics
# Out:
# Comparison of Models:
#            Model              Type      RMSE       MAE      MAPE        R2
# 0           LSTM     Deep Learning  0.126399  0.097297  0.001053  0.992079
# 1        SARIMAX  Machine Learning  0.687457  0.550926  0.005960  0.851625
# 2  Random Forest  Machine Learning  3.451412  3.012947  0.032507 -3.194174

# %%
metrics = ["RMSE", "MAE", "MAPE", "R2"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]
bar_width = 0.5 

for i, metric in enumerate(metrics):
    plt.figure(figsize=(4,4))
    values = df_metrics[metric].values
    plt.bar(df_metrics["Model"], values, color=colors, width=bar_width)
    plt.title(f"Comparison of {metric} Across Models")
    plt.ylabel(metric)
    plt.grid(alpha=0.3, axis='y')
    
    plt.savefig(f"figures/{metric}_comparison.png", bbox_inches='tight')
    
    plt.show()
