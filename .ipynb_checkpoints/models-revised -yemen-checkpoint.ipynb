# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import CubicSpline

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from math import sqrt

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# Set seed 
SEED = 42

np.random.seed(SEED)              
torch.manual_seed(SEED)           
torch.cuda.manual_seed(SEED)     
torch.cuda.manual_seed_all(SEED)

# %%
# Load dataset
df = pd.read_csv('internet_usage.csv')
print("Shape of the Dataset: ", df.shape)
df.head()
# Out:
# Shape of the Dataset:  (217, 26)
#      Country Name Country Code      2000        2001       2002       2003  \
# 0     Afghanistan          AFG        ..  0.00472257  0.0045614  0.0878913
# 1         Albania          ALB  0.114097    0.325798   0.390081     0.9719
# 2         Algeria          DZA  0.491706    0.646114    1.59164    2.19536
# 3  American Samoa          ASM        ..          ..         ..         ..
# 4         Andorra          AND   10.5388          ..    11.2605    13.5464
#
#        2004     2005     2006     2007  ...  2014  2015     2016     2017  \
# 0  0.105809  1.22415  2.10712      1.9  ...     7  8.26       11     13.5
# 1   2.42039  6.04389  9.60999  15.0361  ...  54.3  56.9     59.6     62.4
# 2   4.63448  5.84394  7.37598  9.45119  ...  29.5  38.2  42.9455  47.6911
# 3        ..       ..       ..       ..  ...    ..    ..       ..       ..
# 4    26.838  37.6058  48.9368    70.87  ...  86.1  87.9     89.7  91.5675
#
#       2018     2019     2020     2021     2022     2023
# 0     16.8     17.6     18.4       ..       ..       ..
# 1     65.4  68.5504  72.2377  79.3237  82.6137  83.1356
# 2  49.0385  58.9776  60.6534  66.2356  71.2432       ..
# 3       ..       ..       ..       ..       ..       ..
# 4       ..  90.7187  93.2056  93.8975  94.4855       ..
#
# [5 rows x 26 columns]

# %%
# Take data for Germany
df_yemen = df[df['Country Name'] == 'Yemen, Rep.']
df_yemen
# Out:
#     Country Name Country Code       2000       2001      2002      2003  \
# 214  Yemen, Rep.          YEM  0.0825004  0.0908025  0.518796  0.604734
#
#          2004    2005     2006  2007  ...   2014     2015     2016     2017  \
# 214  0.881223  1.0486  1.24782  5.01  ...  22.55  24.0854  24.5792  26.7184
#
#     2018 2019     2020     2021     2022 2023
# 214   ..   ..  13.8152  14.8881  17.6948   ..
#
# [1 rows x 26 columns]

# %%
# Preprocess the dataset
df_yemen = df_yemen.drop(columns=['Country Code'])
df_yemen_transposed = df_yemen.T
df_yemen_transposed = df_yemen_transposed.reset_index()
df_yemen_transposed.columns = ['Time', 'Penetration']
df_yemen_transposed['Penetration'] = pd.to_numeric(df_yemen_transposed['Penetration'], errors='coerce')
df_yemen_transposed = df_yemen_transposed.dropna()

# %%
# Plot internet penetration rate over years
plt.figure(figsize=(8, 5))
plt.plot(df_yemen_transposed['Time'], df_yemen_transposed['Penetration'], marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Penetration')
plt.title('Penetration Over Years')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("figures/penetration-over-years.png", bbox_inches='tight')
plt.show()

# %%
# Print Total number of datapoints before Interpolation
total_datapoints = len(df_yemen_transposed)
print("Total number of datapoints before interpolation: ", total_datapoints)
# Out:
# Total number of datapoints before interpolation:  21

# %%
# Interpolate dataset to get weekly penetration rates (WITH NOISE)
df = df_yemen_transposed.copy()
df['Time'] = pd.to_numeric(df['Time'], errors='coerce')
df['Penetration'] = pd.to_numeric(df['Penetration'], errors='coerce')

weekly_dates = pd.date_range(start=f"{int(df['Time'].min())}-01-01",
                             end=f"{int(df['Time'].max())}-12-31",
                             freq='7D')

weekly_years = weekly_dates.year + (weekly_dates.day_of_year - 1) / 365.25

cs = CubicSpline(df['Time'], df['Penetration'])
weekly_penetration = cs(weekly_years)

noise = np.random.normal(0, 0.1, size=len(weekly_penetration))
weekly_penetration_noisy = weekly_penetration + noise

df_weekly = pd.DataFrame({
    'Date': weekly_dates,
    'Penetration': weekly_penetration_noisy
})

print(len(df_weekly), "total points")
# Out:
# 1201 total points

# %%
#Plot Datapoints after interpolation ----------#
# Plot first 100 points
plt.figure(figsize=(8, 5))
plt.plot(df_weekly['Date'][:100], df_weekly['Penetration'][:100], marker='o', color='green')
plt.title("Internet Penetration - First 100 Points")
plt.xlabel("Date")
plt.ylabel("Penetration (%)")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig("figures/interpolated-penetration-first-100-points.png", bbox_inches='tight')
plt.show()

# Plot whole dataset
plt.figure(figsize=(8, 5))
plt.plot(df_weekly['Date'], df_weekly['Penetration'], marker='o', color='blue')
plt.title("Internet Penetration - Full Dataset")
plt.xlabel("Date")
plt.ylabel("Penetration (%)")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig("figures/interpolated-penetration-whole-dataset.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Deep Learning Model (Bi-LSTM)**

# %%
#Prepare Dataset for forecasting
class TimeSeriesDataset(Dataset):
    def __init__(self, data, seq_length=64):
        self.seq_length = seq_length
        self.series = data['Penetration'].values.astype(np.float32)

    def __len__(self):
        return len(self.series) - self.seq_length

    def __getitem__(self, idx):
        x = self.series[idx:idx+self.seq_length].reshape(-1, 1)
        y = self.series[idx + self.seq_length]
        return torch.tensor(x), torch.tensor(y)

# %%
# -------------------- Define LSTM Model --------------------
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=2, dropout=0.3, bidirectional=True):
        super(LSTMModel, self).__init__()
        
        self.bidirectional = bidirectional
        
        # LSTM layer
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )
        
        # Determine number of directions (1 for uni, 2 for bi)
        direction_factor = 2 if bidirectional else 1
        
        # Fully connected output layer
        self.fc = nn.Linear(hidden_size * direction_factor, 1)
        
        # Dropout layer
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x):
        out, _ = self.lstm(x)             # LSTM output (batch, seq_len, hidden_size * directions)
        out = out[:, -1, :]               # Take last time step
        out = self.dropout(out)           # Apply dropout
        out = self.fc(out)                # Fully connected layer
        return out.squeeze(1)             # Remove extra dimension for output

# %%
#Preprocess data chronologically
df_weekly_lstm = df_weekly.sort_values('Date').reset_index(drop=True)

# %%
# Total dataset size
dataset_size = len(df_weekly_lstm)

# Compute split sizes
train_size = int(dataset_size * 0.7)
val_size = int(dataset_size * 0.15)
test_size = dataset_size - train_size - val_size  # remaining 15%

# Split the dataframe
train_df = df_weekly_lstm.iloc[:train_size].reset_index(drop=True)
val_df = df_weekly_lstm.iloc[train_size:train_size+val_size].reset_index(drop=True)
test_df = df_weekly_lstm.iloc[train_size+val_size:].reset_index(drop=True)

# Check sizes
print(len(train_df), len(val_df), len(test_df))
# Out:
# 840 180 181

# %%
#Scale the target variable (only on train, then apply to test)
# Initialize scaler
scaler_y = StandardScaler()

# Fit on train target
train_df['Penetration'] = scaler_y.fit_transform(train_df[['Penetration']])

# Apply to validation and test
val_df['Penetration'] = scaler_y.transform(val_df[['Penetration']])
test_df['Penetration'] = scaler_y.transform(test_df[['Penetration']])

# %%
seq_length = 64

# Create TimeSeriesDataset objects
train_dataset = TimeSeriesDataset(train_df, seq_length=seq_length)
val_dataset = TimeSeriesDataset(val_df, seq_length=seq_length)
test_dataset = TimeSeriesDataset(test_df, seq_length=seq_length)

# Create DataLoaders
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
print("Number of sequences in training set: ", len(train_dataset))
print("Number of sequences in validation set: ", len(val_dataset))
print("Number of sequences in test set: ", len(test_dataset))

# Number of batches
print("Number of batches in training set: ", len(train_loader))
print("Number of batches in validation set: ", len(val_loader))
print("Number of batches in test set: ", len(test_loader))
# Out:
# Number of sequences in training set:  776
# Number of sequences in validation set:  116
# Number of sequences in test set:  117
# Number of batches in training set:  49
# Number of batches in validation set:  8
# Number of batches in test set:  8

# %%
# Initialize model, loss, optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMModel(input_size=1, hidden_size=64, num_layers=2).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
best_r2 = -np.inf
best_model_path = "best_lstm_model.pth"

train_losses = []
val_losses = []

epochs = 300
for epoch in range(epochs):
    model.train()
    total_train_loss = 0

    # Training
    for x_batch, y_batch in train_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        output = model(x_batch)
        loss = criterion(output, y_batch)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item() * x_batch.size(0)

    avg_train_loss = total_train_loss / len(train_loader.dataset)
    train_losses.append(avg_train_loss)

    # Validation
    model.eval()
    total_val_loss = 0
    y_true = []
    y_pred = []

    with torch.no_grad():
        for x_batch, y_batch in val_loader:  
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            output = model(x_batch)
            loss = criterion(output, y_batch)
            total_val_loss += loss.item() * x_batch.size(0)

            y_true.extend(y_batch.cpu().numpy())
            y_pred.extend(output.cpu().numpy())

    avg_val_loss = total_val_loss / len(val_loader.dataset)
    val_losses.append(avg_val_loss)

    # Inverse transform to compute R2
    y_true_inv = scaler_y.inverse_transform(np.array(y_true).reshape(-1, 1)).flatten()
    y_pred_inv = scaler_y.inverse_transform(np.array(y_pred).reshape(-1, 1)).flatten()
    r2 = r2_score(y_true_inv, y_pred_inv)

    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {avg_train_loss:.6f} - Val Loss: {avg_val_loss:.6f} - R2: {r2:.4f}")

    # Save best model
    if r2 > best_r2:
        best_r2 = r2
        torch.save(model.state_dict(), best_model_path)
# Out:
# Epoch 1/300 - Train Loss: 0.718691 - Val Loss: 0.221778 - R2: -0.3911
# Epoch 2/300 - Train Loss: 0.798460 - Val Loss: 0.554550 - R2: -2.4785
# Epoch 3/300 - Train Loss: 0.239063 - Val Loss: 0.125621 - R2: 0.2120
# Epoch 4/300 - Train Loss: 0.362996 - Val Loss: 0.104045 - R2: 0.3474
# Epoch 5/300 - Train Loss: 0.099457 - Val Loss: 0.049340 - R2: 0.6905
# Epoch 6/300 - Train Loss: 0.059947 - Val Loss: 0.033077 - R2: 0.7925
# Epoch 7/300 - Train Loss: 0.035455 - Val Loss: 0.016481 - R2: 0.8966
# Epoch 8/300 - Train Loss: 0.022696 - Val Loss: 0.009769 - R2: 0.9387
# Epoch 9/300 - Train Loss: 0.021266 - Val Loss: 0.007032 - R2: 0.9559
# Epoch 10/300 - Train Loss: 0.016382 - Val Loss: 0.005211 - R2: 0.9673
# Epoch 11/300 - Train Loss: 0.014056 - Val Loss: 0.005186 - R2: 0.9675
# Epoch 12/300 - Train Loss: 0.014259 - Val Loss: 0.003279 - R2: 0.9794
# Epoch 13/300 - Train Loss: 0.013458 - Val Loss: 0.003054 - R2: 0.9808
# Epoch 14/300 - Train Loss: 0.015387 - Val Loss: 0.003017 - R2: 0.9811
# Epoch 15/300 - Train Loss: 0.011772 - Val Loss: 0.001836 - R2: 0.9885
# Epoch 16/300 - Train Loss: 0.010677 - Val Loss: 0.002007 - R2: 0.9874
# Epoch 17/300 - Train Loss: 0.011852 - Val Loss: 0.001752 - R2: 0.9890
# Epoch 18/300 - Train Loss: 0.009871 - Val Loss: 0.001051 - R2: 0.9934
# Epoch 19/300 - Train Loss: 0.010166 - Val Loss: 0.004242 - R2: 0.9734
# Epoch 20/300 - Train Loss: 0.009151 - Val Loss: 0.012308 - R2: 0.9228
# Epoch 21/300 - Train Loss: 0.008246 - Val Loss: 0.007033 - R2: 0.9559
# Epoch 22/300 - Train Loss: 0.009694 - Val Loss: 0.001466 - R2: 0.9908
# Epoch 23/300 - Train Loss: 0.015639 - Val Loss: 0.002650 - R2: 0.9834
# Epoch 24/300 - Train Loss: 0.025472 - Val Loss: 0.008800 - R2: 0.9448
# Epoch 25/300 - Train Loss: 0.023973 - Val Loss: 0.019947 - R2: 0.8749
# Epoch 26/300 - Train Loss: 0.021599 - Val Loss: 0.007825 - R2: 0.9509
# Epoch 27/300 - Train Loss: 0.012451 - Val Loss: 0.003025 - R2: 0.9810
# Epoch 28/300 - Train Loss: 0.008061 - Val Loss: 0.002080 - R2: 0.9869
# Epoch 29/300 - Train Loss: 0.008526 - Val Loss: 0.003208 - R2: 0.9799
# Epoch 30/300 - Train Loss: 0.008046 - Val Loss: 0.009246 - R2: 0.9420
# Epoch 31/300 - Train Loss: 0.008131 - Val Loss: 0.023428 - R2: 0.8530
# Epoch 32/300 - Train Loss: 0.008405 - Val Loss: 0.002971 - R2: 0.9814
# Epoch 33/300 - Train Loss: 0.006927 - Val Loss: 0.001789 - R2: 0.9888
# Epoch 34/300 - Train Loss: 0.011982 - Val Loss: 0.006376 - R2: 0.9600
# Epoch 35/300 - Train Loss: 0.010574 - Val Loss: 0.003881 - R2: 0.9757
# Epoch 36/300 - Train Loss: 0.009027 - Val Loss: 0.000342 - R2: 0.9979
# Epoch 37/300 - Train Loss: 0.010657 - Val Loss: 0.001389 - R2: 0.9913
# Epoch 38/300 - Train Loss: 0.009901 - Val Loss: 0.001370 - R2: 0.9914
# Epoch 39/300 - Train Loss: 0.013219 - Val Loss: 0.015013 - R2: 0.9058
# Epoch 40/300 - Train Loss: 0.012306 - Val Loss: 0.031223 - R2: 0.8042
# Epoch 41/300 - Train Loss: 0.008676 - Val Loss: 0.004548 - R2: 0.9715
# Epoch 42/300 - Train Loss: 0.007668 - Val Loss: 0.005837 - R2: 0.9634
# Epoch 43/300 - Train Loss: 0.012694 - Val Loss: 0.004422 - R2: 0.9723
# Epoch 44/300 - Train Loss: 0.011742 - Val Loss: 0.007584 - R2: 0.9524
# Epoch 45/300 - Train Loss: 0.011383 - Val Loss: 0.005926 - R2: 0.9628
# Epoch 46/300 - Train Loss: 0.009403 - Val Loss: 0.002295 - R2: 0.9856
# Epoch 47/300 - Train Loss: 0.008286 - Val Loss: 0.005492 - R2: 0.9655
# Epoch 48/300 - Train Loss: 0.009875 - Val Loss: 0.001032 - R2: 0.9935
# Epoch 49/300 - Train Loss: 0.008460 - Val Loss: 0.006523 - R2: 0.9591
# Epoch 50/300 - Train Loss: 0.013057 - Val Loss: 0.008093 - R2: 0.9492
# Epoch 51/300 - Train Loss: 0.006199 - Val Loss: 0.021623 - R2: 0.8644
# Epoch 52/300 - Train Loss: 0.010745 - Val Loss: 0.024662 - R2: 0.8453
# Epoch 53/300 - Train Loss: 0.006061 - Val Loss: 0.027155 - R2: 0.8297
# Epoch 54/300 - Train Loss: 0.010364 - Val Loss: 0.009305 - R2: 0.9416
# Epoch 55/300 - Train Loss: 0.012853 - Val Loss: 0.008254 - R2: 0.9482
# Epoch 56/300 - Train Loss: 0.021292 - Val Loss: 0.007775 - R2: 0.9512
# Epoch 57/300 - Train Loss: 0.027576 - Val Loss: 0.000613 - R2: 0.9962
# Epoch 58/300 - Train Loss: 0.022595 - Val Loss: 0.000571 - R2: 0.9964
# Epoch 59/300 - Train Loss: 0.009916 - Val Loss: 0.008997 - R2: 0.9436
# Epoch 60/300 - Train Loss: 0.011176 - Val Loss: 0.003676 - R2: 0.9769
# Epoch 61/300 - Train Loss: 0.007353 - Val Loss: 0.049788 - R2: 0.6877
# Epoch 62/300 - Train Loss: 0.013507 - Val Loss: 0.008233 - R2: 0.9484
# Epoch 63/300 - Train Loss: 0.011771 - Val Loss: 0.058006 - R2: 0.6361
# Epoch 64/300 - Train Loss: 0.022149 - Val Loss: 0.030314 - R2: 0.8099
# Epoch 65/300 - Train Loss: 0.009392 - Val Loss: 0.041574 - R2: 0.7392
# Epoch 66/300 - Train Loss: 0.019164 - Val Loss: 0.020507 - R2: 0.8714
# Epoch 67/300 - Train Loss: 0.014766 - Val Loss: 0.014489 - R2: 0.9091
# Epoch 68/300 - Train Loss: 0.022545 - Val Loss: 0.007272 - R2: 0.9544
# Epoch 69/300 - Train Loss: 0.021519 - Val Loss: 0.004476 - R2: 0.9719
# Epoch 70/300 - Train Loss: 0.018331 - Val Loss: 0.010495 - R2: 0.9342
# Epoch 71/300 - Train Loss: 0.015821 - Val Loss: 0.005758 - R2: 0.9639
# Epoch 72/300 - Train Loss: 0.013541 - Val Loss: 0.005859 - R2: 0.9632
# Epoch 73/300 - Train Loss: 0.006039 - Val Loss: 0.013507 - R2: 0.9153
# Epoch 74/300 - Train Loss: 0.008874 - Val Loss: 0.004743 - R2: 0.9703
# Epoch 75/300 - Train Loss: 0.011616 - Val Loss: 0.009529 - R2: 0.9402
# Epoch 76/300 - Train Loss: 0.012266 - Val Loss: 0.005069 - R2: 0.9682
# Epoch 77/300 - Train Loss: 0.009276 - Val Loss: 0.010947 - R2: 0.9313
# Epoch 78/300 - Train Loss: 0.013710 - Val Loss: 0.010329 - R2: 0.9352
# Epoch 79/300 - Train Loss: 0.014297 - Val Loss: 0.003492 - R2: 0.9781
# Epoch 80/300 - Train Loss: 0.012079 - Val Loss: 0.014602 - R2: 0.9084
# Epoch 81/300 - Train Loss: 0.014548 - Val Loss: 0.002872 - R2: 0.9820
# Epoch 82/300 - Train Loss: 0.015628 - Val Loss: 0.036381 - R2: 0.7718
# Epoch 83/300 - Train Loss: 0.026795 - Val Loss: 0.004859 - R2: 0.9695
# Epoch 84/300 - Train Loss: 0.023811 - Val Loss: 0.008994 - R2: 0.9436
# Epoch 85/300 - Train Loss: 0.015135 - Val Loss: 0.008938 - R2: 0.9439
# Epoch 86/300 - Train Loss: 0.021644 - Val Loss: 0.027064 - R2: 0.8302
# Epoch 87/300 - Train Loss: 0.025505 - Val Loss: 0.005914 - R2: 0.9629
# Epoch 88/300 - Train Loss: 0.013905 - Val Loss: 0.014510 - R2: 0.9090
# Epoch 89/300 - Train Loss: 0.008960 - Val Loss: 0.029733 - R2: 0.8135
# Epoch 90/300 - Train Loss: 0.008622 - Val Loss: 0.023384 - R2: 0.8533
# Epoch 91/300 - Train Loss: 0.009080 - Val Loss: 0.009894 - R2: 0.9379
# Epoch 92/300 - Train Loss: 0.015136 - Val Loss: 0.006560 - R2: 0.9589
# Epoch 93/300 - Train Loss: 0.020889 - Val Loss: 0.001321 - R2: 0.9917
# Epoch 94/300 - Train Loss: 0.015923 - Val Loss: 0.001536 - R2: 0.9904
# Epoch 95/300 - Train Loss: 0.006960 - Val Loss: 0.000636 - R2: 0.9960
# Epoch 96/300 - Train Loss: 0.007710 - Val Loss: 0.001620 - R2: 0.9898
# Epoch 97/300 - Train Loss: 0.007758 - Val Loss: 0.002235 - R2: 0.9860
# Epoch 98/300 - Train Loss: 0.007216 - Val Loss: 0.009065 - R2: 0.9431
# Epoch 99/300 - Train Loss: 0.007934 - Val Loss: 0.029633 - R2: 0.8141
# Epoch 100/300 - Train Loss: 0.008756 - Val Loss: 0.012622 - R2: 0.9208
# Epoch 101/300 - Train Loss: 0.006681 - Val Loss: 0.008258 - R2: 0.9482
# Epoch 102/300 - Train Loss: 0.011320 - Val Loss: 0.005146 - R2: 0.9677
# Epoch 103/300 - Train Loss: 0.014525 - Val Loss: 0.001792 - R2: 0.9888
# Epoch 104/300 - Train Loss: 0.014881 - Val Loss: 0.013332 - R2: 0.9164
# Epoch 105/300 - Train Loss: 0.014409 - Val Loss: 0.002319 - R2: 0.9855
# Epoch 106/300 - Train Loss: 0.017866 - Val Loss: 0.011215 - R2: 0.9297
# Epoch 107/300 - Train Loss: 0.021763 - Val Loss: 0.012745 - R2: 0.9201
# Epoch 108/300 - Train Loss: 0.024101 - Val Loss: 0.084738 - R2: 0.4685
# Epoch 109/300 - Train Loss: 0.028585 - Val Loss: 0.011666 - R2: 0.9268
# Epoch 110/300 - Train Loss: 0.026112 - Val Loss: 0.060058 - R2: 0.6233
# Epoch 111/300 - Train Loss: 0.036464 - Val Loss: 0.011402 - R2: 0.9285
# Epoch 112/300 - Train Loss: 0.022573 - Val Loss: 0.006149 - R2: 0.9614
# Epoch 113/300 - Train Loss: 0.012542 - Val Loss: 0.003399 - R2: 0.9787
# Epoch 114/300 - Train Loss: 0.012464 - Val Loss: 0.001986 - R2: 0.9875
# Epoch 115/300 - Train Loss: 0.007646 - Val Loss: 0.003167 - R2: 0.9801
# Epoch 116/300 - Train Loss: 0.009067 - Val Loss: 0.008886 - R2: 0.9443
# Epoch 117/300 - Train Loss: 0.009693 - Val Loss: 0.009739 - R2: 0.9389
# Epoch 118/300 - Train Loss: 0.010685 - Val Loss: 0.060433 - R2: 0.6209
# Epoch 119/300 - Train Loss: 0.012531 - Val Loss: 0.009627 - R2: 0.9396
# Epoch 120/300 - Train Loss: 0.012458 - Val Loss: 0.101498 - R2: 0.3633
# Epoch 121/300 - Train Loss: 0.019247 - Val Loss: 0.013319 - R2: 0.9165
# Epoch 122/300 - Train Loss: 0.012613 - Val Loss: 0.026188 - R2: 0.8357
# Epoch 123/300 - Train Loss: 0.015029 - Val Loss: 0.009756 - R2: 0.9388
# Epoch 124/300 - Train Loss: 0.016995 - Val Loss: 0.011886 - R2: 0.9254
# Epoch 125/300 - Train Loss: 0.022498 - Val Loss: 0.015616 - R2: 0.9020
# Epoch 126/300 - Train Loss: 0.016945 - Val Loss: 0.042951 - R2: 0.7306
# Epoch 127/300 - Train Loss: 0.018338 - Val Loss: 0.025928 - R2: 0.8374
# Epoch 128/300 - Train Loss: 0.023438 - Val Loss: 0.066731 - R2: 0.5814
# Epoch 129/300 - Train Loss: 0.027723 - Val Loss: 0.043118 - R2: 0.7295
# Epoch 130/300 - Train Loss: 0.018742 - Val Loss: 0.058780 - R2: 0.6313
# Epoch 131/300 - Train Loss: 0.019884 - Val Loss: 0.005129 - R2: 0.9678
# Epoch 132/300 - Train Loss: 0.017125 - Val Loss: 0.042887 - R2: 0.7310
# Epoch 133/300 - Train Loss: 0.022876 - Val Loss: 0.002658 - R2: 0.9833
# Epoch 134/300 - Train Loss: 0.013347 - Val Loss: 0.000750 - R2: 0.9953
# Epoch 135/300 - Train Loss: 0.029176 - Val Loss: 0.000340 - R2: 0.9979
# Epoch 136/300 - Train Loss: 0.008390 - Val Loss: 0.001145 - R2: 0.9928
# Epoch 137/300 - Train Loss: 0.007230 - Val Loss: 0.000915 - R2: 0.9943
# Epoch 138/300 - Train Loss: 0.006181 - Val Loss: 0.000456 - R2: 0.9971
# Epoch 139/300 - Train Loss: 0.007775 - Val Loss: 0.010104 - R2: 0.9366
# Epoch 140/300 - Train Loss: 0.007882 - Val Loss: 0.001446 - R2: 0.9909
# Epoch 141/300 - Train Loss: 0.007084 - Val Loss: 0.002202 - R2: 0.9862
# Epoch 142/300 - Train Loss: 0.009714 - Val Loss: 0.002836 - R2: 0.9822
# Epoch 143/300 - Train Loss: 0.005896 - Val Loss: 0.002295 - R2: 0.9856
# Epoch 144/300 - Train Loss: 0.006481 - Val Loss: 0.000739 - R2: 0.9954
# Epoch 145/300 - Train Loss: 0.007862 - Val Loss: 0.000880 - R2: 0.9945
# Epoch 146/300 - Train Loss: 0.006776 - Val Loss: 0.001253 - R2: 0.9921
# Epoch 147/300 - Train Loss: 0.007455 - Val Loss: 0.000437 - R2: 0.9973
# Epoch 148/300 - Train Loss: 0.007352 - Val Loss: 0.006960 - R2: 0.9563
# Epoch 149/300 - Train Loss: 0.006944 - Val Loss: 0.013249 - R2: 0.9169
# Epoch 150/300 - Train Loss: 0.006966 - Val Loss: 0.004670 - R2: 0.9707
# Epoch 151/300 - Train Loss: 0.007761 - Val Loss: 0.001616 - R2: 0.9899
# Epoch 152/300 - Train Loss: 0.011613 - Val Loss: 0.001830 - R2: 0.9885
# Epoch 153/300 - Train Loss: 0.009073 - Val Loss: 0.000370 - R2: 0.9977
# Epoch 154/300 - Train Loss: 0.011733 - Val Loss: 0.003011 - R2: 0.9811
# Epoch 155/300 - Train Loss: 0.011929 - Val Loss: 0.013704 - R2: 0.9140
# Epoch 156/300 - Train Loss: 0.008604 - Val Loss: 0.020778 - R2: 0.8697
# Epoch 157/300 - Train Loss: 0.007825 - Val Loss: 0.007297 - R2: 0.9542
# Epoch 158/300 - Train Loss: 0.011372 - Val Loss: 0.003983 - R2: 0.9750
# Epoch 159/300 - Train Loss: 0.014490 - Val Loss: 0.003721 - R2: 0.9767
# Epoch 160/300 - Train Loss: 0.013805 - Val Loss: 0.012358 - R2: 0.9225
# Epoch 161/300 - Train Loss: 0.011190 - Val Loss: 0.012341 - R2: 0.9226
# Epoch 162/300 - Train Loss: 0.011805 - Val Loss: 0.017549 - R2: 0.8899
# Epoch 163/300 - Train Loss: 0.012163 - Val Loss: 0.021064 - R2: 0.8679
# Epoch 164/300 - Train Loss: 0.013315 - Val Loss: 0.035704 - R2: 0.7760
# Epoch 165/300 - Train Loss: 0.015857 - Val Loss: 0.031285 - R2: 0.8038
# Epoch 166/300 - Train Loss: 0.018868 - Val Loss: 0.052187 - R2: 0.6726
# Epoch 167/300 - Train Loss: 0.012277 - Val Loss: 0.035929 - R2: 0.7746
# Epoch 168/300 - Train Loss: 0.012940 - Val Loss: 0.006604 - R2: 0.9586
# Epoch 169/300 - Train Loss: 0.011326 - Val Loss: 0.020717 - R2: 0.8701
# Epoch 170/300 - Train Loss: 0.018590 - Val Loss: 0.002051 - R2: 0.9871
# Epoch 171/300 - Train Loss: 0.011310 - Val Loss: 0.000420 - R2: 0.9974
# Epoch 172/300 - Train Loss: 0.017502 - Val Loss: 0.001870 - R2: 0.9883
# Epoch 173/300 - Train Loss: 0.008288 - Val Loss: 0.000488 - R2: 0.9969
# Epoch 174/300 - Train Loss: 0.007537 - Val Loss: 0.003085 - R2: 0.9807
# Epoch 175/300 - Train Loss: 0.006480 - Val Loss: 0.000575 - R2: 0.9964
# Epoch 176/300 - Train Loss: 0.005426 - Val Loss: 0.000881 - R2: 0.9945
# Epoch 177/300 - Train Loss: 0.007968 - Val Loss: 0.005914 - R2: 0.9629
# Epoch 178/300 - Train Loss: 0.006574 - Val Loss: 0.006193 - R2: 0.9612
# Epoch 179/300 - Train Loss: 0.006720 - Val Loss: 0.001573 - R2: 0.9901
# Epoch 180/300 - Train Loss: 0.010426 - Val Loss: 0.002465 - R2: 0.9845
# Epoch 181/300 - Train Loss: 0.011985 - Val Loss: 0.004292 - R2: 0.9731
# Epoch 182/300 - Train Loss: 0.010465 - Val Loss: 0.000431 - R2: 0.9973
# Epoch 183/300 - Train Loss: 0.006140 - Val Loss: 0.007258 - R2: 0.9545
# Epoch 184/300 - Train Loss: 0.005828 - Val Loss: 0.001649 - R2: 0.9897
# Epoch 185/300 - Train Loss: 0.006052 - Val Loss: 0.001010 - R2: 0.9937
# Epoch 186/300 - Train Loss: 0.011091 - Val Loss: 0.000849 - R2: 0.9947
# Epoch 187/300 - Train Loss: 0.006580 - Val Loss: 0.000821 - R2: 0.9949
# Epoch 188/300 - Train Loss: 0.007922 - Val Loss: 0.001620 - R2: 0.9898
# Epoch 189/300 - Train Loss: 0.007598 - Val Loss: 0.000809 - R2: 0.9949
# Epoch 190/300 - Train Loss: 0.007273 - Val Loss: 0.016705 - R2: 0.8952
# Epoch 191/300 - Train Loss: 0.006531 - Val Loss: 0.002302 - R2: 0.9856
# Epoch 192/300 - Train Loss: 0.007377 - Val Loss: 0.010769 - R2: 0.9325
# Epoch 193/300 - Train Loss: 0.018847 - Val Loss: 0.014898 - R2: 0.9065
# Epoch 194/300 - Train Loss: 0.014112 - Val Loss: 0.019468 - R2: 0.8779
# Epoch 195/300 - Train Loss: 0.028679 - Val Loss: 0.012886 - R2: 0.9192
# Epoch 196/300 - Train Loss: 0.016315 - Val Loss: 0.022358 - R2: 0.8598
# Epoch 197/300 - Train Loss: 0.031292 - Val Loss: 0.014955 - R2: 0.9062
# Epoch 198/300 - Train Loss: 0.018643 - Val Loss: 0.026261 - R2: 0.8353
# Epoch 199/300 - Train Loss: 0.022283 - Val Loss: 0.094409 - R2: 0.4078
# Epoch 200/300 - Train Loss: 0.020854 - Val Loss: 0.010888 - R2: 0.9317
# Epoch 201/300 - Train Loss: 0.017786 - Val Loss: 0.057112 - R2: 0.6418
# Epoch 202/300 - Train Loss: 0.025430 - Val Loss: 0.036009 - R2: 0.7741
# Epoch 203/300 - Train Loss: 0.020795 - Val Loss: 0.007936 - R2: 0.9502
# Epoch 204/300 - Train Loss: 0.009905 - Val Loss: 0.001384 - R2: 0.9913
# Epoch 205/300 - Train Loss: 0.010947 - Val Loss: 0.020819 - R2: 0.8694
# Epoch 206/300 - Train Loss: 0.010492 - Val Loss: 0.000856 - R2: 0.9946
# Epoch 207/300 - Train Loss: 0.008951 - Val Loss: 0.004859 - R2: 0.9695
# Epoch 208/300 - Train Loss: 0.011766 - Val Loss: 0.006708 - R2: 0.9579
# Epoch 209/300 - Train Loss: 0.006394 - Val Loss: 0.000787 - R2: 0.9951
# Epoch 210/300 - Train Loss: 0.010383 - Val Loss: 0.000479 - R2: 0.9970
# Epoch 211/300 - Train Loss: 0.009478 - Val Loss: 0.002397 - R2: 0.9850
# Epoch 212/300 - Train Loss: 0.006670 - Val Loss: 0.003806 - R2: 0.9761
# Epoch 213/300 - Train Loss: 0.006789 - Val Loss: 0.000771 - R2: 0.9952
# Epoch 214/300 - Train Loss: 0.006752 - Val Loss: 0.008611 - R2: 0.9460
# Epoch 215/300 - Train Loss: 0.007009 - Val Loss: 0.001203 - R2: 0.9925
# Epoch 216/300 - Train Loss: 0.005560 - Val Loss: 0.000631 - R2: 0.9960
# Epoch 217/300 - Train Loss: 0.008865 - Val Loss: 0.000273 - R2: 0.9983
# Epoch 218/300 - Train Loss: 0.005746 - Val Loss: 0.000217 - R2: 0.9986
# Epoch 219/300 - Train Loss: 0.005532 - Val Loss: 0.000335 - R2: 0.9979
# Epoch 220/300 - Train Loss: 0.006809 - Val Loss: 0.001410 - R2: 0.9912
# Epoch 221/300 - Train Loss: 0.007244 - Val Loss: 0.002367 - R2: 0.9852
# Epoch 222/300 - Train Loss: 0.005698 - Val Loss: 0.003941 - R2: 0.9753
# Epoch 223/300 - Train Loss: 0.006533 - Val Loss: 0.002953 - R2: 0.9815
# Epoch 224/300 - Train Loss: 0.006206 - Val Loss: 0.008403 - R2: 0.9473
# Epoch 225/300 - Train Loss: 0.005442 - Val Loss: 0.002741 - R2: 0.9828
# Epoch 226/300 - Train Loss: 0.005970 - Val Loss: 0.001290 - R2: 0.9919
# Epoch 227/300 - Train Loss: 0.007724 - Val Loss: 0.000798 - R2: 0.9950
# Epoch 228/300 - Train Loss: 0.009900 - Val Loss: 0.001290 - R2: 0.9919
# Epoch 229/300 - Train Loss: 0.006984 - Val Loss: 0.005865 - R2: 0.9632
# Epoch 230/300 - Train Loss: 0.008962 - Val Loss: 0.030907 - R2: 0.8061
# Epoch 231/300 - Train Loss: 0.012582 - Val Loss: 0.071834 - R2: 0.5494
# Epoch 232/300 - Train Loss: 0.014463 - Val Loss: 0.018006 - R2: 0.8871
# Epoch 233/300 - Train Loss: 0.006986 - Val Loss: 0.031663 - R2: 0.8014
# Epoch 234/300 - Train Loss: 0.012007 - Val Loss: 0.003804 - R2: 0.9761
# Epoch 235/300 - Train Loss: 0.020765 - Val Loss: 0.009876 - R2: 0.9381
# Epoch 236/300 - Train Loss: 0.008189 - Val Loss: 0.018867 - R2: 0.8817
# Epoch 237/300 - Train Loss: 0.011436 - Val Loss: 0.014906 - R2: 0.9065
# Epoch 238/300 - Train Loss: 0.009734 - Val Loss: 0.005236 - R2: 0.9672
# Epoch 239/300 - Train Loss: 0.017408 - Val Loss: 0.001380 - R2: 0.9913
# Epoch 240/300 - Train Loss: 0.012158 - Val Loss: 0.002816 - R2: 0.9823
# Epoch 241/300 - Train Loss: 0.011457 - Val Loss: 0.005343 - R2: 0.9665
# Epoch 242/300 - Train Loss: 0.009247 - Val Loss: 0.006573 - R2: 0.9588
# Epoch 243/300 - Train Loss: 0.009487 - Val Loss: 0.001825 - R2: 0.9886
# Epoch 244/300 - Train Loss: 0.008027 - Val Loss: 0.004518 - R2: 0.9717
# Epoch 245/300 - Train Loss: 0.006469 - Val Loss: 0.004343 - R2: 0.9728
# Epoch 246/300 - Train Loss: 0.006039 - Val Loss: 0.009178 - R2: 0.9424
# Epoch 247/300 - Train Loss: 0.007632 - Val Loss: 0.001269 - R2: 0.9920
# Epoch 248/300 - Train Loss: 0.008252 - Val Loss: 0.000685 - R2: 0.9957
# Epoch 249/300 - Train Loss: 0.012152 - Val Loss: 0.007477 - R2: 0.9531
# Epoch 250/300 - Train Loss: 0.009295 - Val Loss: 0.003823 - R2: 0.9760
# Epoch 251/300 - Train Loss: 0.012357 - Val Loss: 0.022390 - R2: 0.8596
# Epoch 252/300 - Train Loss: 0.009211 - Val Loss: 0.009948 - R2: 0.9376
# Epoch 253/300 - Train Loss: 0.009778 - Val Loss: 0.017414 - R2: 0.8908
# Epoch 254/300 - Train Loss: 0.007969 - Val Loss: 0.002938 - R2: 0.9816
# Epoch 255/300 - Train Loss: 0.010081 - Val Loss: 0.004909 - R2: 0.9692
# Epoch 256/300 - Train Loss: 0.008628 - Val Loss: 0.040395 - R2: 0.7466
# Epoch 257/300 - Train Loss: 0.013647 - Val Loss: 0.009124 - R2: 0.9428
# Epoch 258/300 - Train Loss: 0.009618 - Val Loss: 0.007987 - R2: 0.9499
# Epoch 259/300 - Train Loss: 0.029014 - Val Loss: 0.023840 - R2: 0.8505
# Epoch 260/300 - Train Loss: 0.029664 - Val Loss: 0.005630 - R2: 0.9647
# Epoch 261/300 - Train Loss: 0.019998 - Val Loss: 0.082167 - R2: 0.4846
# Epoch 262/300 - Train Loss: 0.015853 - Val Loss: 0.024140 - R2: 0.8486
# Epoch 263/300 - Train Loss: 0.012803 - Val Loss: 0.003895 - R2: 0.9756
# Epoch 264/300 - Train Loss: 0.010257 - Val Loss: 0.005239 - R2: 0.9671
# Epoch 265/300 - Train Loss: 0.011554 - Val Loss: 0.013335 - R2: 0.9164
# Epoch 266/300 - Train Loss: 0.007353 - Val Loss: 0.003273 - R2: 0.9795
# Epoch 267/300 - Train Loss: 0.010119 - Val Loss: 0.005330 - R2: 0.9666
# Epoch 268/300 - Train Loss: 0.012693 - Val Loss: 0.005168 - R2: 0.9676
# Epoch 269/300 - Train Loss: 0.011218 - Val Loss: 0.010329 - R2: 0.9352
# Epoch 270/300 - Train Loss: 0.007715 - Val Loss: 0.014142 - R2: 0.9113
# Epoch 271/300 - Train Loss: 0.008320 - Val Loss: 0.002591 - R2: 0.9837
# Epoch 272/300 - Train Loss: 0.009006 - Val Loss: 0.025689 - R2: 0.8389
# Epoch 273/300 - Train Loss: 0.011039 - Val Loss: 0.009671 - R2: 0.9393
# Epoch 274/300 - Train Loss: 0.009114 - Val Loss: 0.014167 - R2: 0.9111
# Epoch 275/300 - Train Loss: 0.016436 - Val Loss: 0.004042 - R2: 0.9746
# Epoch 276/300 - Train Loss: 0.011165 - Val Loss: 0.004605 - R2: 0.9711
# Epoch 277/300 - Train Loss: 0.014782 - Val Loss: 0.012246 - R2: 0.9232
# Epoch 278/300 - Train Loss: 0.012856 - Val Loss: 0.016255 - R2: 0.8980
# Epoch 279/300 - Train Loss: 0.009390 - Val Loss: 0.003895 - R2: 0.9756
# Epoch 280/300 - Train Loss: 0.007081 - Val Loss: 0.011783 - R2: 0.9261
# Epoch 281/300 - Train Loss: 0.008544 - Val Loss: 0.006277 - R2: 0.9606
# Epoch 282/300 - Train Loss: 0.005942 - Val Loss: 0.004093 - R2: 0.9743
# Epoch 283/300 - Train Loss: 0.011976 - Val Loss: 0.001113 - R2: 0.9930
# Epoch 284/300 - Train Loss: 0.009064 - Val Loss: 0.000392 - R2: 0.9975
# Epoch 285/300 - Train Loss: 0.008633 - Val Loss: 0.002567 - R2: 0.9839
# Epoch 286/300 - Train Loss: 0.007040 - Val Loss: 0.006171 - R2: 0.9613
# Epoch 287/300 - Train Loss: 0.008367 - Val Loss: 0.002490 - R2: 0.9844
# Epoch 288/300 - Train Loss: 0.005925 - Val Loss: 0.002861 - R2: 0.9821
# Epoch 289/300 - Train Loss: 0.006297 - Val Loss: 0.013864 - R2: 0.9130
# Epoch 290/300 - Train Loss: 0.006470 - Val Loss: 0.013159 - R2: 0.9175
# Epoch 291/300 - Train Loss: 0.008131 - Val Loss: 0.001783 - R2: 0.9888
# Epoch 292/300 - Train Loss: 0.013208 - Val Loss: 0.000950 - R2: 0.9940
# Epoch 293/300 - Train Loss: 0.014492 - Val Loss: 0.007604 - R2: 0.9523
# Epoch 294/300 - Train Loss: 0.015987 - Val Loss: 0.005608 - R2: 0.9648
# Epoch 295/300 - Train Loss: 0.009123 - Val Loss: 0.001015 - R2: 0.9936
# Epoch 296/300 - Train Loss: 0.006226 - Val Loss: 0.004011 - R2: 0.9748
# Epoch 297/300 - Train Loss: 0.006039 - Val Loss: 0.013973 - R2: 0.9124
# Epoch 298/300 - Train Loss: 0.006085 - Val Loss: 0.009414 - R2: 0.9409
# Epoch 299/300 - Train Loss: 0.007384 - Val Loss: 0.002726 - R2: 0.9829
# Epoch 300/300 - Train Loss: 0.011841 - Val Loss: 0.001475 - R2: 0.9907

# %%
# Plot loss curve for lstm
plt.figure(figsize=(8, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid(True)
plt.savefig("figures/lstm-loss-curve.png", bbox_inches='tight')
plt.show()

# %%
# Evaluate LSTM model after training

best_model = LSTMModel(input_size=1, hidden_size=64, num_layers=2).to(device)
best_model.load_state_dict(torch.load(best_model_path))
best_model.to(device)
best_model.eval()

y_true_test, y_pred_test = [], []
with torch.no_grad():
    for x_batch, y_batch in test_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        output = best_model(x_batch)
        y_true_test.extend(y_batch.cpu().numpy())
        y_pred_test.extend(output.cpu().numpy())

y_true_test_inv = scaler_y.inverse_transform(np.array(y_true_test).reshape(-1, 1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(np.array(y_pred_test).reshape(-1, 1)).flatten()

lstm_rmse = np.sqrt(mean_squared_error(y_true_test_inv, y_pred_test_inv))
lstm_mae  = mean_absolute_error(y_true_test_inv, y_pred_test_inv)
lstm_mape = mean_absolute_percentage_error(y_true_test_inv, y_pred_test_inv)
lstm_r2   = r2_score(y_true_test_inv, y_pred_test_inv)

print(f"LSTM RMSE: {lstm_rmse:.4f}")
print(f"LSTM MAE : {lstm_mae:.4f}")
print(f"LSTM MAPE: {lstm_mape:.4f}")
print(f"LSTM R2  : {lstm_r2:.4f}")
# Out:
# LSTM RMSE: 0.1493
# LSTM MAE : 0.1117
# LSTM MAPE: 0.0066
# LSTM R2  : 0.9850

# %%
# Function to get predictions
def get_predictions(dataloader, model):
    preds, trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(device)
            output = model(x_batch)
            preds.extend(output.cpu().numpy())
            trues.extend(y_batch.cpu().numpy())
    return np.array(trues), np.array(preds)

# -------------------- Test Set Plot --------------------
y_true_test, y_pred_test = get_predictions(test_loader, best_model)
y_true_test_inv = scaler_y.inverse_transform(y_true_test.reshape(-1,1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(y_pred_test.reshape(-1,1)).flatten()

plt.figure(figsize=(8,5))
plt.plot(y_true_test_inv, label="Real", color="blue")
plt.plot(y_pred_test_inv, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.grid(alpha=0.3)
plt.savefig("figures/real-vs-predicted-test-set-lstm.png", bbox_inches='tight')
plt.show()

# -------------------- Full Dataset Plot (Train + Val + Test) --------------------
# Get predictions for all splits
y_true_train, y_pred_train = get_predictions(train_loader, best_model)
y_true_val, y_pred_val = get_predictions(val_loader, best_model)
y_true_test, y_pred_test = get_predictions(test_loader, best_model)

# Inverse transform
y_true_train_inv = scaler_y.inverse_transform(y_true_train.reshape(-1,1)).flatten()
y_pred_train_inv = scaler_y.inverse_transform(y_pred_train.reshape(-1,1)).flatten()
y_true_val_inv = scaler_y.inverse_transform(y_true_val.reshape(-1,1)).flatten()
y_pred_val_inv = scaler_y.inverse_transform(y_pred_val.reshape(-1,1)).flatten()
y_true_test_inv = scaler_y.inverse_transform(y_true_test.reshape(-1,1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(y_pred_test.reshape(-1,1)).flatten()

# Concatenate all
y_true_all = np.concatenate([y_true_train_inv, y_true_val_inv, y_true_test_inv])
y_pred_all = np.concatenate([y_pred_train_inv, y_pred_val_inv, y_pred_test_inv])

# Split indices
train_end = len(y_true_train_inv)
val_end = train_end + len(y_true_val_inv)

# Plot
plt.figure(figsize=(12,5))
plt.plot(y_true_all, label="Real", color="blue")
plt.plot(y_pred_all, label="Predicted", color="red", linestyle="--")

# Mark train/val/test splits
plt.axvline(x=train_end, color="green", linestyle=":", label="Train/Val Split")
plt.axvline(x=val_end, color="black", linestyle=":", label="Val/Test Split")

plt.title("Real vs Predicted - Full Dataset (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("figures/real-vs-predicted-full-dataset-lstm.png", bbox_inches='tight')
plt.show()

# %%
# Plot residual plot and distribution of residual plot for lstm model

y_true_test = np.array(y_true_test)
y_pred_test = np.array(y_pred_test)
residuals_test = y_true_test - y_pred_test

# Residual Plot
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-lstm.png", bbox_inches='tight')
plt.show()

#Distribution of Residuals
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, kde=True, bins=30, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution (LSTM)")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distributions-lstm.png", bbox_inches='tight')
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

# -------------------- Compute residuals --------------------
# Residuals on test set
residuals = y_true_test_inv - y_pred_test_inv

# -------------------- Plot ACF of Residuals --------------------
plt.figure(figsize=(12,4))
plot_acf(residuals, lags=40, ax=plt.gca())
plt.title("ACF of Residuals")
plt.show()

# -------------------- Plot PACF of Residuals --------------------
plt.figure(figsize=(12,4))
plot_pacf(residuals, lags=40, ax=plt.gca())
plt.title("PACF of Residuals")
plt.show()

# -------------------- Ljung-Box Test --------------------
# Null hypothesis: residuals are independently distributed
lb_test = acorr_ljungbox(residuals, lags=[10, 15, 20], return_df=True)

print("Ljung-Box test results for residuals:")
print(lb_test)
# Out:
# Ljung-Box test results for residuals:
#       lb_stat  lb_pvalue
# 10  36.745524   0.000063
# 15  39.737509   0.000497
# 20  50.166298   0.000210

# %% [markdown]
# ## **Machine Learning Model 1: Random Forest**

# %%
# Prepare dataset for Random Forest

df_weekly = df_weekly.sort_values('Date').reset_index(drop=True)
series = df_weekly['Penetration'].values

def create_features(series, seq_length=64):
    X, y = [], []
    for i in range(seq_length, len(series)):
        lag_window = series[i-seq_length:i].copy()
        diff_window = np.diff(lag_window, prepend=lag_window[0])
        feature_row = np.concatenate([lag_window, diff_window])
        X.append(feature_row)
        y.append(series[i])
    return np.array(X), np.array(y)

seq_length = 64
X, y = create_features(series, seq_length)

time_index = np.arange(len(series))[seq_length:].reshape(-1,1)
X = np.hstack([X, time_index])

# Train/test split (first 80% train, last 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Scale features
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1,1)).flatten()
y_test_scaled = scaler_y.transform(y_test.reshape(-1,1)).flatten()

# %%
# Train Random Forest
rf_model = RandomForestRegressor(n_estimators=300, max_depth=15, random_state=42)
rf_model.fit(X_train_scaled, y_train_scaled)
# Out:
# RandomForestRegressor(max_depth=15, n_estimators=300, random_state=42)

# %%
# Predictions
y_pred_train_scaled = rf_model.predict(X_train_scaled)
y_pred_test_scaled = rf_model.predict(X_test_scaled)

y_pred_train = scaler_y.inverse_transform(y_pred_train_scaled.reshape(-1,1)).flatten()
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled.reshape(-1,1)).flatten()

# Metrics
rf_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
rf_mae  = mean_absolute_error(y_test, y_pred_test)
rf_mape = mean_absolute_percentage_error(y_test, y_pred_test)
rf_r2   = r2_score(y_test, y_pred_test)

print(f"Random Forest RMSE: {rf_rmse:.4f}")
print(f"Random Forest MAE : {rf_mae:.4f}")
print(f"Random Forest MAPE: {rf_mape:.4f}")
print(f"Random Forest R2  : {rf_r2:.4f}")
# Out:
# Random Forest RMSE: 2.2334
# Random Forest MAE : 1.7341
# Random Forest MAPE: 0.1139
# Random Forest R2  : -0.6065

# %%
#Real vs Predicted (Test Set) 
plt.figure(figsize=(8,5))
plt.plot(y_test, label="Real", color="blue")
plt.plot(y_pred_test, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (Random Forest)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-test-set-rf.png", bbox_inches='tight')
plt.show()

#Real vs Predicted (Whole Dataset)
y_true_all = np.concatenate([y_train, y_test])
y_pred_all = np.concatenate([y_pred_train, y_pred_test])

plt.figure(figsize=(8,5))
plt.plot(range(len(y_true_all)), y_true_all, label="Real", color="blue")
plt.plot(range(len(y_pred_all)), y_pred_all, label="Predicted", color="red", linestyle="--")
plt.axvline(x=len(y_train), color="black", linestyle=":", label="Train/Test Split")
plt.title("Real vs Predicted - Whole Dataset (Random Forest)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-whole-dataset-rf.png", bbox_inches='tight')
plt.show()

# %%
#Residual Plot (Test Set)
residuals_test = y_test - y_pred_test
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot (Random Forest)")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-rf.png", bbox_inches='tight')
plt.show()

#Residual Distribution (Test Set)
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, kde=True, bins=30, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution (Random Forest)")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distributions-rf.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Machine Learning Model 2: SARIMAX**

# %%
#Prepare series
df_weekly = df_weekly.sort_values('Date').reset_index(drop=True)
series = df_weekly['Penetration']

#Train/Test Split
train_size = int(len(series) * 0.8)
train_series = series[:train_size]
test_series = series[train_size:]

# %%
import itertools
import warnings
from statsmodels.tsa.statespace.sarimax import SARIMAX
from tqdm import tqdm

warnings.filterwarnings("ignore") 

# -------------------- parameter ranges --------------------
p = q = range(0, 3)          # AR & MA terms
d = [1]                       # differencing usually 1
P = Q = range(0, 2)           # Seasonal AR & MA terms
D = [1]                        # seasonal differencing
s = 52                         # Weekly seasonality for yearly data

# Generate all combinations
pdq = list(itertools.product(p, d, q))
seasonal_pdq = list(itertools.product(P, D, Q))

# -------------------- Grid Search --------------------
best_aic = float("inf")
best_order = None
best_seasonal_order = None

for order in tqdm(pdq, desc="SARIMAX p,d,q grid"):
    for seasonal_order in seasonal_pdq:
        try:
            model = SARIMAX(
                train_series,
                order=order,
                seasonal_order=(seasonal_order[0], seasonal_order[1], seasonal_order[2], s),
                enforce_stationarity=False,
                enforce_invertibility=False
            )
            results = model.fit(disp=False)
            
            if results.aic < best_aic:
                best_aic = results.aic
                best_order = order
                best_seasonal_order = seasonal_order
        except:
            continue

# -------------------- Print best parameters --------------------
print("Best SARIMAX parameters based on AIC:")
print(f"Order (p,d,q): {best_order}")
print(f"Seasonal order (P,D,Q,s): {best_seasonal_order + (s,)}")
print(f"Best AIC: {best_aic:.4f}")
# Out:
# SARIMAX p,d,q grid: 100%|███████████████████████████████████████████████████████████████| 9/9 [44:17<00:00, 295.31s/it]
# Best SARIMAX parameters based on AIC:
# Order (p,d,q): (1, 1, 2)
# Seasonal order (P,D,Q,s): (0, 1, 1, 52)
# Best AIC: -1196.1643
#
# Final model fitted.

# %%
# Fit SARIMAX model

sarimax_model = SARIMAX(
    train_series,
    order=(1,1,2),
    seasonal_order=(0,1,1,52),
    enforce_stationarity=False,
    enforce_invertibility=False
)
sarimax_result = sarimax_model.fit(disp=False)

# %%
# --------- Predictions ---------
train_pred = sarimax_result.predict(start=0, end=len(train_series)-1, dynamic=False)

# Forecast test
test_pred = sarimax_result.forecast(steps=len(test_series))

# --------- Metrics ---------
sarimax_rmse = np.sqrt(mean_squared_error(test_series, test_pred))
sarimax_mae  = mean_absolute_error(test_series, test_pred)
sarimax_mape = mean_absolute_percentage_error(test_series, test_pred)
sarimax_r2   = r2_score(test_series, test_pred)

print(f"SARIMAX RMSE: {sarimax_rmse:.4f}")
print(f"SARIMAX MAE : {sarimax_mae:.4f}")
print(f"SARIMAX MAPE: {sarimax_mape:.4f}")
print(f"SARIMAX R2  : {sarimax_r2:.4f}")
# Out:
# SARIMAX RMSE: 7.6998
# SARIMAX MAE : 7.3497
# SARIMAX MAPE: 0.4683
# SARIMAX R2  : -13.5418

# %%
#Plot Test Set(Actual vs Predicted) 
plt.figure(figsize=(8,5))
plt.plot(test_series.values, label="Real", color="blue")
plt.plot(test_pred.values, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (SARIMAX)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-test-set-sarimax.png", bbox_inches='tight')

plt.show()

# --------- Plot Whole Series ---------
all_real = np.concatenate([train_series.values, test_series.values])
all_pred = np.concatenate([train_pred.values, test_pred.values])

plt.figure(figsize=(8,5))
plt.plot(range(len(all_real)), all_real, label="Real", color="blue")
plt.plot(range(len(all_pred)), all_pred, label="Predicted", color="red", linestyle="--")
plt.axvline(x=len(train_series), color="black", linestyle=":", label="Train/Test Split")
plt.title("Real vs Predicted - Whole Datast (SARIMAX)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-whole-dataset-sarimax.png", bbox_inches='tight')
plt.show()

# %%
#Residual Plot
residuals_test = test_series.values - test_pred.values
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot SARIMAX")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-sarimax.png", bbox_inches='tight')
plt.show()

#Residual Distribution
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, bins=30, kde=True, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution SARIMAX")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distribution-sarimax.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Comparison of All three models**

# %%
#Metrics for each model
data = {
    "Model": ["LSTM", "SARIMAX", "Random Forest"],
    "Type":  ["Deep Learning", "Machine Learning", "Machine Learning"],
    "RMSE":  [lstm_rmse, sarimax_rmse, rf_rmse],
    "MAE":   [lstm_mae, sarimax_mae, rf_mae],
    "MAPE":  [lstm_mape, sarimax_mape, rf_mape],
    "R2":    [lstm_r2, sarimax_r2, rf_r2]
}

df_metrics = pd.DataFrame(data)

#Display the table
print("Comparison of Models:")
df_metrics
# Out:
# Comparison of Models:
#            Model              Type      RMSE       MAE      MAPE         R2
# 0           LSTM     Deep Learning  0.149258  0.111725  0.006643   0.984988
# 1        SARIMAX  Machine Learning  7.699765  7.349701  0.468292 -13.541825
# 2  Random Forest  Machine Learning  2.233446  1.734068  0.113884  -0.606527

# %%
metrics = ["RMSE", "MAE", "MAPE", "R2"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]
bar_width = 0.5 

for i, metric in enumerate(metrics):
    plt.figure(figsize=(4,4))
    values = df_metrics[metric].values
    plt.bar(df_metrics["Model"], values, color=colors, width=bar_width)
    plt.title(f"Comparison of {metric} Across Models")
    plt.ylabel(metric)
    plt.grid(alpha=0.3, axis='y')
    
    plt.savefig(f"figures/{metric}_comparison.png", bbox_inches='tight')
    
    plt.show()
