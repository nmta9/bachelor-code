# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import CubicSpline

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from math import sqrt

from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# Set seed 
SEED = 42

np.random.seed(SEED)              
torch.manual_seed(SEED)           
torch.cuda.manual_seed(SEED)     
torch.cuda.manual_seed_all(SEED)

# %%
# Load dataset
df = pd.read_csv('internet_usage.csv')
print("Shape of the Dataset: ", df.shape)
df.head()
# Out:
# Shape of the Dataset:  (217, 26)
#      Country Name Country Code      2000        2001       2002       2003  \
# 0     Afghanistan          AFG        ..  0.00472257  0.0045614  0.0878913
# 1         Albania          ALB  0.114097    0.325798   0.390081     0.9719
# 2         Algeria          DZA  0.491706    0.646114    1.59164    2.19536
# 3  American Samoa          ASM        ..          ..         ..         ..
# 4         Andorra          AND   10.5388          ..    11.2605    13.5464
#
#        2004     2005     2006     2007  ...  2014  2015     2016     2017  \
# 0  0.105809  1.22415  2.10712      1.9  ...     7  8.26       11     13.5
# 1   2.42039  6.04389  9.60999  15.0361  ...  54.3  56.9     59.6     62.4
# 2   4.63448  5.84394  7.37598  9.45119  ...  29.5  38.2  42.9455  47.6911
# 3        ..       ..       ..       ..  ...    ..    ..       ..       ..
# 4    26.838  37.6058  48.9368    70.87  ...  86.1  87.9     89.7  91.5675
#
#       2018     2019     2020     2021     2022     2023
# 0     16.8     17.6     18.4       ..       ..       ..
# 1     65.4  68.5504  72.2377  79.3237  82.6137  83.1356
# 2  49.0385  58.9776  60.6534  66.2356  71.2432       ..
# 3       ..       ..       ..       ..       ..       ..
# 4       ..  90.7187  93.2056  93.8975  94.4855       ..
#
# [5 rows x 26 columns]

# %%
# Take data for Germany
df_germany = df[df['Country Name'] == 'Germany']
df_germany
# Out:
#    Country Name Country Code     2000     2001   2002  2003   2004   2005  \
# 73      Germany          DEU  30.2163  31.6509  48.82  55.9  64.73  68.71
#
#      2006   2007  ...     2014     2015     2016     2017     2018     2019  \
# 73  72.16  75.16  ...  86.1937  87.5898  84.1652  84.3942  87.0371  88.1345
#
#        2020     2021     2022     2023
# 73  89.8129  91.4306  91.6298  92.4764
#
# [1 rows x 26 columns]

# %%
# Preprocess the dataset
df_germany = df_germany.drop(columns=['Country Code'])
df_germany_transposed = df_germany.T
df_germany_transposed = df_germany_transposed.reset_index()
df_germany_transposed.columns = ['Time', 'Penetration']
df_germany_transposed['Penetration'] = pd.to_numeric(df_germany_transposed['Penetration'], errors='coerce')
df_germany_transposed = df_germany_transposed.dropna()

# %%
# Plot internet penetration rate over years
plt.figure(figsize=(8, 5))
plt.plot(df_germany_transposed['Time'], df_germany_transposed['Penetration'], marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Penetration')
plt.title('Penetration Over Years')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("figures/penetration-over-years.png", bbox_inches='tight')
plt.show()

# %%
# Print Total number of datapoints before Interpolation
total_datapoints = len(df_germany_transposed)
print("Total number of datapoints before interpolation: ", total_datapoints)
# Out:
# Total number of datapoints before interpolation:  24

# %%
# Interpolate dataset to get weekly penetration rates (WITH NOISE)
df = df_germany_transposed.copy()
df['Time'] = pd.to_numeric(df['Time'], errors='coerce')
df['Penetration'] = pd.to_numeric(df['Penetration'], errors='coerce')

weekly_dates = pd.date_range(start=f"{int(df['Time'].min())}-01-01",
                             end=f"{int(df['Time'].max())}-12-31",
                             freq='7D')

weekly_years = weekly_dates.year + (weekly_dates.day_of_year - 1) / 365.25

cs = CubicSpline(df['Time'], df['Penetration'])
weekly_penetration = cs(weekly_years)

noise = np.random.normal(0, 0.1, size=len(weekly_penetration))
# weekly_penetration_noisy = weekly_penetration + noise

df_weekly = pd.DataFrame({
    'Date': weekly_dates,
    'Penetration': weekly_penetration
})

print(len(df_weekly), "total points")
# Out:
# 1253 total points

# %%
#Plot Datapoints after interpolation ----------#
# Plot first 100 points
plt.figure(figsize=(8, 5))
plt.plot(df_weekly['Date'][:100], df_weekly['Penetration'][:100], marker='o', color='green')
plt.title("Internet Penetration - First 100 Points")
plt.xlabel("Date")
plt.ylabel("Penetration (%)")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig("figures/interpolated-penetration-first-100-points.png", bbox_inches='tight')
plt.show()

# Plot whole dataset
plt.figure(figsize=(8, 5))
plt.plot(df_weekly['Date'], df_weekly['Penetration'], marker='o', color='blue')
plt.title("Internet Penetration - Full Dataset")
plt.xlabel("Date")
plt.ylabel("Penetration (%)")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig("figures/interpolated-penetration-whole-dataset.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Deep Learning Model (Bi-LSTM)**

# %%
#Prepare Dataset for forecasting
class TimeSeriesDataset(Dataset):
    def __init__(self, data, seq_length=64):
        self.seq_length = seq_length
        self.series = data['Penetration'].values.astype(np.float32)

    def __len__(self):
        return len(self.series) - self.seq_length

    def __getitem__(self, idx):
        x = self.series[idx:idx+self.seq_length].reshape(-1, 1)
        y = self.series[idx + self.seq_length]
        return torch.tensor(x), torch.tensor(y)

# %%
# -------------------- Define LSTM Model --------------------
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=2, dropout=0.3, bidirectional=True):
        super(LSTMModel, self).__init__()
        
        self.bidirectional = bidirectional
        
        # LSTM layer
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=bidirectional
        )
        
        # Determine number of directions (1 for uni, 2 for bi)
        direction_factor = 2 if bidirectional else 1
        
        # Fully connected output layer
        self.fc = nn.Linear(hidden_size * direction_factor, 1)
        
        # Dropout layer
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x):
        out, _ = self.lstm(x)             # LSTM output (batch, seq_len, hidden_size * directions)
        out = out[:, -1, :]               # Take last time step
        out = self.dropout(out)           # Apply dropout
        out = self.fc(out)                # Fully connected layer
        return out.squeeze(1)             # Remove extra dimension for output

# %%
#Preprocess data chronologically
df_weekly_lstm = df_weekly.sort_values('Date').reset_index(drop=True)

# %%
# Total dataset size
dataset_size = len(df_weekly_lstm)

# Compute split sizes
train_size = int(dataset_size * 0.7)
val_size = int(dataset_size * 0.15)
test_size = dataset_size - train_size - val_size  # remaining 15%

# Split the dataframe
train_df = df_weekly_lstm.iloc[:train_size].reset_index(drop=True)
val_df = df_weekly_lstm.iloc[train_size:train_size+val_size].reset_index(drop=True)
test_df = df_weekly_lstm.iloc[train_size+val_size:].reset_index(drop=True)

# Check sizes
print(len(train_df), len(val_df), len(test_df))
# Out:
# 877 187 189

# %%
#Scale the target variable (only on train, then apply to test)
# Initialize scaler
scaler_y = StandardScaler()

# Fit on train target
train_df['Penetration'] = scaler_y.fit_transform(train_df[['Penetration']])

# Apply to validation and test
val_df['Penetration'] = scaler_y.transform(val_df[['Penetration']])
test_df['Penetration'] = scaler_y.transform(test_df[['Penetration']])

# %%
seq_length = 64

# Create TimeSeriesDataset objects
train_dataset = TimeSeriesDataset(train_df, seq_length=seq_length)
val_dataset = TimeSeriesDataset(val_df, seq_length=seq_length)
test_dataset = TimeSeriesDataset(test_df, seq_length=seq_length)

# Create DataLoaders
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
print("Number of sequences in training set: ", len(train_dataset))
print("Number of sequences in validation set: ", len(val_dataset))
print("Number of sequences in test set: ", len(test_dataset))

# Number of batches
print("Number of batches in training set: ", len(train_loader))
print("Number of batches in validation set: ", len(val_loader))
print("Number of batches in test set: ", len(test_loader))
# Out:
# Number of sequences in training set:  813
# Number of sequences in validation set:  123
# Number of sequences in test set:  125
# Number of batches in training set:  51
# Number of batches in validation set:  8
# Number of batches in test set:  8

# %%
# Initialize model, loss, optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMModel(input_size=1, hidden_size=64, num_layers=2).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
best_r2 = -np.inf
best_model_path = "best_lstm_model.pth"

train_losses = []
val_losses = []

epochs = 300
for epoch in range(epochs):
    model.train()
    total_train_loss = 0

    # Training
    for x_batch, y_batch in train_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        output = model(x_batch)
        loss = criterion(output, y_batch)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item() * x_batch.size(0)

    avg_train_loss = total_train_loss / len(train_loader.dataset)
    train_losses.append(avg_train_loss)

    # Validation
    model.eval()
    total_val_loss = 0
    y_true = []
    y_pred = []

    with torch.no_grad():
        for x_batch, y_batch in val_loader:  
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            output = model(x_batch)
            loss = criterion(output, y_batch)
            total_val_loss += loss.item() * x_batch.size(0)

            y_true.extend(y_batch.cpu().numpy())
            y_pred.extend(output.cpu().numpy())

    avg_val_loss = total_val_loss / len(val_loader.dataset)
    val_losses.append(avg_val_loss)

    # Inverse transform to compute R2
    y_true_inv = scaler_y.inverse_transform(np.array(y_true).reshape(-1, 1)).flatten()
    y_pred_inv = scaler_y.inverse_transform(np.array(y_pred).reshape(-1, 1)).flatten()
    r2 = r2_score(y_true_inv, y_pred_inv)

    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {avg_train_loss:.6f} - Val Loss: {avg_val_loss:.6f} - R2: {r2:.4f}")

    # Save best model
    if r2 > best_r2:
        best_r2 = r2
        torch.save(model.state_dict(), best_model_path)
# Out:
# Epoch 1/300 - Train Loss: 0.378245 - Val Loss: 0.068430 - R2: -19.1152
# Epoch 2/300 - Train Loss: 0.153982 - Val Loss: 0.003276 - R2: 0.0369
# Epoch 3/300 - Train Loss: 0.124276 - Val Loss: 0.021606 - R2: -5.3513
# Epoch 4/300 - Train Loss: 0.220761 - Val Loss: 0.006805 - R2: -1.0003
# Epoch 5/300 - Train Loss: 0.094435 - Val Loss: 0.007877 - R2: -1.3156
# Epoch 6/300 - Train Loss: 0.041277 - Val Loss: 0.007383 - R2: -1.1702
# Epoch 7/300 - Train Loss: 0.027956 - Val Loss: 0.007984 - R2: -1.3470
# Epoch 8/300 - Train Loss: 0.016459 - Val Loss: 0.006694 - R2: -0.9678
# Epoch 9/300 - Train Loss: 0.049819 - Val Loss: 0.003192 - R2: 0.0617
# Epoch 10/300 - Train Loss: 0.028367 - Val Loss: 0.005128 - R2: -0.5075
# Epoch 11/300 - Train Loss: 0.071280 - Val Loss: 0.007958 - R2: -1.3393
# Epoch 12/300 - Train Loss: 0.039672 - Val Loss: 0.005488 - R2: -0.6133
# Epoch 13/300 - Train Loss: 0.060767 - Val Loss: 0.002778 - R2: 0.1834
# Epoch 14/300 - Train Loss: 0.033224 - Val Loss: 0.006123 - R2: -0.8000
# Epoch 15/300 - Train Loss: 0.054881 - Val Loss: 0.001803 - R2: 0.4700
# Epoch 16/300 - Train Loss: 0.024290 - Val Loss: 0.004273 - R2: -0.2562
# Epoch 17/300 - Train Loss: 0.034039 - Val Loss: 0.001674 - R2: 0.5080
# Epoch 18/300 - Train Loss: 0.019489 - Val Loss: 0.002158 - R2: 0.3656
# Epoch 19/300 - Train Loss: 0.033437 - Val Loss: 0.001470 - R2: 0.5679
# Epoch 20/300 - Train Loss: 0.020651 - Val Loss: 0.002673 - R2: 0.2142
# Epoch 21/300 - Train Loss: 0.031123 - Val Loss: 0.000849 - R2: 0.7503
# Epoch 22/300 - Train Loss: 0.018503 - Val Loss: 0.003043 - R2: 0.1054
# Epoch 23/300 - Train Loss: 0.035145 - Val Loss: 0.000589 - R2: 0.8268
# Epoch 24/300 - Train Loss: 0.019467 - Val Loss: 0.001906 - R2: 0.4398
# Epoch 25/300 - Train Loss: 0.029799 - Val Loss: 0.001611 - R2: 0.5265
# Epoch 26/300 - Train Loss: 0.017237 - Val Loss: 0.003965 - R2: -0.1654
# Epoch 27/300 - Train Loss: 0.027836 - Val Loss: 0.000703 - R2: 0.7932
# Epoch 28/300 - Train Loss: 0.017134 - Val Loss: 0.002412 - R2: 0.2911
# Epoch 29/300 - Train Loss: 0.028134 - Val Loss: 0.000454 - R2: 0.8667
# Epoch 30/300 - Train Loss: 0.016621 - Val Loss: 0.004730 - R2: -0.3905
# Epoch 31/300 - Train Loss: 0.025267 - Val Loss: 0.000986 - R2: 0.7102
# Epoch 32/300 - Train Loss: 0.014120 - Val Loss: 0.001857 - R2: 0.4541
# Epoch 33/300 - Train Loss: 0.025217 - Val Loss: 0.001812 - R2: 0.4675
# Epoch 34/300 - Train Loss: 0.017259 - Val Loss: 0.003262 - R2: 0.0412
# Epoch 35/300 - Train Loss: 0.030413 - Val Loss: 0.000483 - R2: 0.8581
# Epoch 36/300 - Train Loss: 0.021069 - Val Loss: 0.002972 - R2: 0.1263
# Epoch 37/300 - Train Loss: 0.034509 - Val Loss: 0.000447 - R2: 0.8686
# Epoch 38/300 - Train Loss: 0.018440 - Val Loss: 0.002242 - R2: 0.3410
# Epoch 39/300 - Train Loss: 0.026228 - Val Loss: 0.000601 - R2: 0.8234
# Epoch 40/300 - Train Loss: 0.013363 - Val Loss: 0.001661 - R2: 0.5116
# Epoch 41/300 - Train Loss: 0.020747 - Val Loss: 0.001577 - R2: 0.5364
# Epoch 42/300 - Train Loss: 0.014748 - Val Loss: 0.004628 - R2: -0.3604
# Epoch 43/300 - Train Loss: 0.021516 - Val Loss: 0.000488 - R2: 0.8566
# Epoch 44/300 - Train Loss: 0.018034 - Val Loss: 0.001722 - R2: 0.4938
# Epoch 45/300 - Train Loss: 0.027020 - Val Loss: 0.000379 - R2: 0.8886
# Epoch 46/300 - Train Loss: 0.018086 - Val Loss: 0.002363 - R2: 0.3053
# Epoch 47/300 - Train Loss: 0.028438 - Val Loss: 0.000329 - R2: 0.9033
# Epoch 48/300 - Train Loss: 0.018634 - Val Loss: 0.003134 - R2: 0.0788
# Epoch 49/300 - Train Loss: 0.028780 - Val Loss: 0.000479 - R2: 0.8592
# Epoch 50/300 - Train Loss: 0.019163 - Val Loss: 0.002144 - R2: 0.3697
# Epoch 51/300 - Train Loss: 0.030081 - Val Loss: 0.001011 - R2: 0.7027
# Epoch 52/300 - Train Loss: 0.017057 - Val Loss: 0.002959 - R2: 0.1302
# Epoch 53/300 - Train Loss: 0.025405 - Val Loss: 0.000393 - R2: 0.8844
# Epoch 54/300 - Train Loss: 0.018233 - Val Loss: 0.003498 - R2: -0.0284
# Epoch 55/300 - Train Loss: 0.029405 - Val Loss: 0.000377 - R2: 0.8893
# Epoch 56/300 - Train Loss: 0.017009 - Val Loss: 0.001266 - R2: 0.6278
# Epoch 57/300 - Train Loss: 0.025145 - Val Loss: 0.000386 - R2: 0.8865
# Epoch 58/300 - Train Loss: 0.015031 - Val Loss: 0.002575 - R2: 0.2431
# Epoch 59/300 - Train Loss: 0.020685 - Val Loss: 0.000915 - R2: 0.7310
# Epoch 60/300 - Train Loss: 0.012856 - Val Loss: 0.001323 - R2: 0.6110
# Epoch 61/300 - Train Loss: 0.017567 - Val Loss: 0.001166 - R2: 0.6574
# Epoch 62/300 - Train Loss: 0.014237 - Val Loss: 0.002571 - R2: 0.2443
# Epoch 63/300 - Train Loss: 0.020847 - Val Loss: 0.000586 - R2: 0.8278
# Epoch 64/300 - Train Loss: 0.017375 - Val Loss: 0.003237 - R2: 0.0485
# Epoch 65/300 - Train Loss: 0.029256 - Val Loss: 0.000518 - R2: 0.8479
# Epoch 66/300 - Train Loss: 0.018389 - Val Loss: 0.002131 - R2: 0.3737
# Epoch 67/300 - Train Loss: 0.028056 - Val Loss: 0.001744 - R2: 0.4872
# Epoch 68/300 - Train Loss: 0.016947 - Val Loss: 0.001692 - R2: 0.5027
# Epoch 69/300 - Train Loss: 0.024196 - Val Loss: 0.000614 - R2: 0.8195
# Epoch 70/300 - Train Loss: 0.017365 - Val Loss: 0.000784 - R2: 0.7696
# Epoch 71/300 - Train Loss: 0.023687 - Val Loss: 0.001014 - R2: 0.7020
# Epoch 72/300 - Train Loss: 0.017298 - Val Loss: 0.003216 - R2: 0.0547
# Epoch 73/300 - Train Loss: 0.024183 - Val Loss: 0.000505 - R2: 0.8516
# Epoch 74/300 - Train Loss: 0.017714 - Val Loss: 0.001184 - R2: 0.6519
# Epoch 75/300 - Train Loss: 0.026185 - Val Loss: 0.002326 - R2: 0.3164
# Epoch 76/300 - Train Loss: 0.016327 - Val Loss: 0.002167 - R2: 0.3631
# Epoch 77/300 - Train Loss: 0.024641 - Val Loss: 0.002069 - R2: 0.3919
# Epoch 78/300 - Train Loss: 0.017450 - Val Loss: 0.001387 - R2: 0.5924
# Epoch 79/300 - Train Loss: 0.026597 - Val Loss: 0.001039 - R2: 0.6947
# Epoch 80/300 - Train Loss: 0.017773 - Val Loss: 0.000785 - R2: 0.7692
# Epoch 81/300 - Train Loss: 0.025312 - Val Loss: 0.000655 - R2: 0.8076
# Epoch 82/300 - Train Loss: 0.016546 - Val Loss: 0.000989 - R2: 0.7092
# Epoch 83/300 - Train Loss: 0.022512 - Val Loss: 0.001324 - R2: 0.6109
# Epoch 84/300 - Train Loss: 0.015219 - Val Loss: 0.000983 - R2: 0.7109
# Epoch 85/300 - Train Loss: 0.025887 - Val Loss: 0.001428 - R2: 0.5803
# Epoch 86/300 - Train Loss: 0.014992 - Val Loss: 0.001335 - R2: 0.6076
# Epoch 87/300 - Train Loss: 0.024678 - Val Loss: 0.000396 - R2: 0.8835
# Epoch 88/300 - Train Loss: 0.017544 - Val Loss: 0.001122 - R2: 0.6703
# Epoch 89/300 - Train Loss: 0.027488 - Val Loss: 0.002005 - R2: 0.4105
# Epoch 90/300 - Train Loss: 0.014864 - Val Loss: 0.001015 - R2: 0.7015
# Epoch 91/300 - Train Loss: 0.022562 - Val Loss: 0.000606 - R2: 0.8220
# Epoch 92/300 - Train Loss: 0.015979 - Val Loss: 0.000745 - R2: 0.7809
# Epoch 93/300 - Train Loss: 0.023896 - Val Loss: 0.001465 - R2: 0.5693
# Epoch 94/300 - Train Loss: 0.015410 - Val Loss: 0.002067 - R2: 0.3923
# Epoch 95/300 - Train Loss: 0.023172 - Val Loss: 0.000448 - R2: 0.8682
# Epoch 96/300 - Train Loss: 0.015190 - Val Loss: 0.001509 - R2: 0.5565
# Epoch 97/300 - Train Loss: 0.022410 - Val Loss: 0.000373 - R2: 0.8904
# Epoch 98/300 - Train Loss: 0.012722 - Val Loss: 0.000866 - R2: 0.7455
# Epoch 99/300 - Train Loss: 0.021329 - Val Loss: 0.000437 - R2: 0.8716
# Epoch 100/300 - Train Loss: 0.012910 - Val Loss: 0.001725 - R2: 0.4929
# Epoch 101/300 - Train Loss: 0.018498 - Val Loss: 0.000441 - R2: 0.8703
# Epoch 102/300 - Train Loss: 0.013422 - Val Loss: 0.001328 - R2: 0.6096
# Epoch 103/300 - Train Loss: 0.018881 - Val Loss: 0.000431 - R2: 0.8732
# Epoch 104/300 - Train Loss: 0.013141 - Val Loss: 0.001911 - R2: 0.4383
# Epoch 105/300 - Train Loss: 0.019038 - Val Loss: 0.000380 - R2: 0.8883
# Epoch 106/300 - Train Loss: 0.014610 - Val Loss: 0.001118 - R2: 0.6713
# Epoch 107/300 - Train Loss: 0.022134 - Val Loss: 0.000478 - R2: 0.8595
# Epoch 108/300 - Train Loss: 0.016433 - Val Loss: 0.001091 - R2: 0.6792
# Epoch 109/300 - Train Loss: 0.026808 - Val Loss: 0.000866 - R2: 0.7455
# Epoch 110/300 - Train Loss: 0.016411 - Val Loss: 0.002222 - R2: 0.3470
# Epoch 111/300 - Train Loss: 0.028239 - Val Loss: 0.000372 - R2: 0.8908
# Epoch 112/300 - Train Loss: 0.016311 - Val Loss: 0.001807 - R2: 0.4689
# Epoch 113/300 - Train Loss: 0.023317 - Val Loss: 0.000459 - R2: 0.8649
# Epoch 114/300 - Train Loss: 0.015811 - Val Loss: 0.000997 - R2: 0.7068
# Epoch 115/300 - Train Loss: 0.023380 - Val Loss: 0.000679 - R2: 0.8004
# Epoch 116/300 - Train Loss: 0.013463 - Val Loss: 0.000575 - R2: 0.8310
# Epoch 117/300 - Train Loss: 0.018011 - Val Loss: 0.000212 - R2: 0.9378
# Epoch 118/300 - Train Loss: 0.013202 - Val Loss: 0.000699 - R2: 0.7944
# Epoch 119/300 - Train Loss: 0.018356 - Val Loss: 0.000497 - R2: 0.8540
# Epoch 120/300 - Train Loss: 0.012997 - Val Loss: 0.000481 - R2: 0.8586
# Epoch 121/300 - Train Loss: 0.016356 - Val Loss: 0.000212 - R2: 0.9377
# Epoch 122/300 - Train Loss: 0.012063 - Val Loss: 0.000896 - R2: 0.7367
# Epoch 123/300 - Train Loss: 0.017290 - Val Loss: 0.000209 - R2: 0.9386
# Epoch 124/300 - Train Loss: 0.013027 - Val Loss: 0.001985 - R2: 0.4164
# Epoch 125/300 - Train Loss: 0.017583 - Val Loss: 0.001118 - R2: 0.6714
# Epoch 126/300 - Train Loss: 0.016277 - Val Loss: 0.002015 - R2: 0.4078
# Epoch 127/300 - Train Loss: 0.022939 - Val Loss: 0.000317 - R2: 0.9067
# Epoch 128/300 - Train Loss: 0.017054 - Val Loss: 0.001598 - R2: 0.5303
# Epoch 129/300 - Train Loss: 0.024886 - Val Loss: 0.000366 - R2: 0.8923
# Epoch 130/300 - Train Loss: 0.014555 - Val Loss: 0.001441 - R2: 0.5763
# Epoch 131/300 - Train Loss: 0.019564 - Val Loss: 0.000232 - R2: 0.9318
# Epoch 132/300 - Train Loss: 0.013998 - Val Loss: 0.001926 - R2: 0.4340
# Epoch 133/300 - Train Loss: 0.019035 - Val Loss: 0.000240 - R2: 0.9293
# Epoch 134/300 - Train Loss: 0.014469 - Val Loss: 0.001293 - R2: 0.6199
# Epoch 135/300 - Train Loss: 0.018978 - Val Loss: 0.000219 - R2: 0.9357
# Epoch 136/300 - Train Loss: 0.013638 - Val Loss: 0.001398 - R2: 0.5891
# Epoch 137/300 - Train Loss: 0.016855 - Val Loss: 0.000375 - R2: 0.8897
# Epoch 138/300 - Train Loss: 0.012551 - Val Loss: 0.000941 - R2: 0.7235
# Epoch 139/300 - Train Loss: 0.016439 - Val Loss: 0.000375 - R2: 0.8898
# Epoch 140/300 - Train Loss: 0.013383 - Val Loss: 0.000754 - R2: 0.7783
# Epoch 141/300 - Train Loss: 0.016940 - Val Loss: 0.000225 - R2: 0.9339
# Epoch 142/300 - Train Loss: 0.013544 - Val Loss: 0.002096 - R2: 0.3837
# Epoch 143/300 - Train Loss: 0.017027 - Val Loss: 0.000320 - R2: 0.9059
# Epoch 144/300 - Train Loss: 0.012853 - Val Loss: 0.000358 - R2: 0.8948
# Epoch 145/300 - Train Loss: 0.017526 - Val Loss: 0.000366 - R2: 0.8923
# Epoch 146/300 - Train Loss: 0.012489 - Val Loss: 0.001659 - R2: 0.5123
# Epoch 147/300 - Train Loss: 0.015516 - Val Loss: 0.000345 - R2: 0.8987
# Epoch 148/300 - Train Loss: 0.012692 - Val Loss: 0.001709 - R2: 0.4977
# Epoch 149/300 - Train Loss: 0.017996 - Val Loss: 0.000532 - R2: 0.8435
# Epoch 150/300 - Train Loss: 0.015143 - Val Loss: 0.000344 - R2: 0.8988
# Epoch 151/300 - Train Loss: 0.020199 - Val Loss: 0.000224 - R2: 0.9342
# Epoch 152/300 - Train Loss: 0.012407 - Val Loss: 0.001726 - R2: 0.4927
# Epoch 153/300 - Train Loss: 0.015700 - Val Loss: 0.000415 - R2: 0.8780
# Epoch 154/300 - Train Loss: 0.010798 - Val Loss: 0.001962 - R2: 0.4232
# Epoch 155/300 - Train Loss: 0.013811 - Val Loss: 0.000258 - R2: 0.9240
# Epoch 156/300 - Train Loss: 0.010568 - Val Loss: 0.000504 - R2: 0.8520
# Epoch 157/300 - Train Loss: 0.014956 - Val Loss: 0.000222 - R2: 0.9346
# Epoch 158/300 - Train Loss: 0.013801 - Val Loss: 0.001094 - R2: 0.6785
# Epoch 159/300 - Train Loss: 0.018905 - Val Loss: 0.000465 - R2: 0.8634
# Epoch 160/300 - Train Loss: 0.015206 - Val Loss: 0.003164 - R2: 0.0700
# Epoch 161/300 - Train Loss: 0.021981 - Val Loss: 0.000506 - R2: 0.8511
# Epoch 162/300 - Train Loss: 0.017654 - Val Loss: 0.000796 - R2: 0.7661
# Epoch 163/300 - Train Loss: 0.026360 - Val Loss: 0.000199 - R2: 0.9416
# Epoch 164/300 - Train Loss: 0.014925 - Val Loss: 0.000574 - R2: 0.8312
# Epoch 165/300 - Train Loss: 0.023019 - Val Loss: 0.000213 - R2: 0.9375
# Epoch 166/300 - Train Loss: 0.015063 - Val Loss: 0.000528 - R2: 0.8447
# Epoch 167/300 - Train Loss: 0.020722 - Val Loss: 0.000156 - R2: 0.9541
# Epoch 168/300 - Train Loss: 0.013705 - Val Loss: 0.000342 - R2: 0.8995
# Epoch 169/300 - Train Loss: 0.015399 - Val Loss: 0.000535 - R2: 0.8427
# Epoch 170/300 - Train Loss: 0.012039 - Val Loss: 0.000745 - R2: 0.7811
# Epoch 171/300 - Train Loss: 0.015717 - Val Loss: 0.000682 - R2: 0.7996
# Epoch 172/300 - Train Loss: 0.012161 - Val Loss: 0.000291 - R2: 0.9145
# Epoch 173/300 - Train Loss: 0.015412 - Val Loss: 0.000116 - R2: 0.9659
# Epoch 174/300 - Train Loss: 0.011648 - Val Loss: 0.002837 - R2: 0.1661
# Epoch 175/300 - Train Loss: 0.014386 - Val Loss: 0.000199 - R2: 0.9415
# Epoch 176/300 - Train Loss: 0.013142 - Val Loss: 0.001356 - R2: 0.6014
# Epoch 177/300 - Train Loss: 0.017100 - Val Loss: 0.000188 - R2: 0.9448
# Epoch 178/300 - Train Loss: 0.013045 - Val Loss: 0.000770 - R2: 0.7737
# Epoch 179/300 - Train Loss: 0.017316 - Val Loss: 0.000210 - R2: 0.9383
# Epoch 180/300 - Train Loss: 0.011353 - Val Loss: 0.000622 - R2: 0.8172
# Epoch 181/300 - Train Loss: 0.017147 - Val Loss: 0.000148 - R2: 0.9566
# Epoch 182/300 - Train Loss: 0.014419 - Val Loss: 0.000697 - R2: 0.7951
# Epoch 183/300 - Train Loss: 0.016751 - Val Loss: 0.000498 - R2: 0.8535
# Epoch 184/300 - Train Loss: 0.015019 - Val Loss: 0.000490 - R2: 0.8560
# Epoch 185/300 - Train Loss: 0.016943 - Val Loss: 0.000167 - R2: 0.9510
# Epoch 186/300 - Train Loss: 0.013285 - Val Loss: 0.000513 - R2: 0.8493
# Epoch 187/300 - Train Loss: 0.016778 - Val Loss: 0.000146 - R2: 0.9570
# Epoch 188/300 - Train Loss: 0.012659 - Val Loss: 0.000260 - R2: 0.9237
# Epoch 189/300 - Train Loss: 0.016887 - Val Loss: 0.000475 - R2: 0.8603
# Epoch 190/300 - Train Loss: 0.013635 - Val Loss: 0.000601 - R2: 0.8235
# Epoch 191/300 - Train Loss: 0.019365 - Val Loss: 0.000124 - R2: 0.9637
# Epoch 192/300 - Train Loss: 0.012876 - Val Loss: 0.000395 - R2: 0.8839
# Epoch 193/300 - Train Loss: 0.016478 - Val Loss: 0.000088 - R2: 0.9741
# Epoch 194/300 - Train Loss: 0.012353 - Val Loss: 0.000319 - R2: 0.9062
# Epoch 195/300 - Train Loss: 0.015757 - Val Loss: 0.000121 - R2: 0.9644
# Epoch 196/300 - Train Loss: 0.012494 - Val Loss: 0.001186 - R2: 0.6514
# Epoch 197/300 - Train Loss: 0.014783 - Val Loss: 0.000152 - R2: 0.9552
# Epoch 198/300 - Train Loss: 0.011158 - Val Loss: 0.000229 - R2: 0.9327
# Epoch 199/300 - Train Loss: 0.015943 - Val Loss: 0.000818 - R2: 0.7596
# Epoch 200/300 - Train Loss: 0.010524 - Val Loss: 0.000264 - R2: 0.9224
# Epoch 201/300 - Train Loss: 0.013366 - Val Loss: 0.000237 - R2: 0.9303
# Epoch 202/300 - Train Loss: 0.010709 - Val Loss: 0.000283 - R2: 0.9169
# Epoch 203/300 - Train Loss: 0.012266 - Val Loss: 0.000385 - R2: 0.8869
# Epoch 204/300 - Train Loss: 0.010241 - Val Loss: 0.000880 - R2: 0.7415
# Epoch 205/300 - Train Loss: 0.014202 - Val Loss: 0.000671 - R2: 0.8028
# Epoch 206/300 - Train Loss: 0.011233 - Val Loss: 0.000328 - R2: 0.9035
# Epoch 207/300 - Train Loss: 0.014435 - Val Loss: 0.000161 - R2: 0.9526
# Epoch 208/300 - Train Loss: 0.012526 - Val Loss: 0.000467 - R2: 0.8627
# Epoch 209/300 - Train Loss: 0.016483 - Val Loss: 0.000229 - R2: 0.9327
# Epoch 210/300 - Train Loss: 0.014045 - Val Loss: 0.000299 - R2: 0.9121
# Epoch 211/300 - Train Loss: 0.018132 - Val Loss: 0.000192 - R2: 0.9435
# Epoch 212/300 - Train Loss: 0.012060 - Val Loss: 0.000226 - R2: 0.9335
# Epoch 213/300 - Train Loss: 0.016422 - Val Loss: 0.000274 - R2: 0.9196
# Epoch 214/300 - Train Loss: 0.013378 - Val Loss: 0.001449 - R2: 0.5740
# Epoch 215/300 - Train Loss: 0.017136 - Val Loss: 0.000150 - R2: 0.9559
# Epoch 216/300 - Train Loss: 0.013520 - Val Loss: 0.000279 - R2: 0.9181
# Epoch 217/300 - Train Loss: 0.016202 - Val Loss: 0.000492 - R2: 0.8554
# Epoch 218/300 - Train Loss: 0.013416 - Val Loss: 0.000798 - R2: 0.7654
# Epoch 219/300 - Train Loss: 0.020106 - Val Loss: 0.000090 - R2: 0.9734
# Epoch 220/300 - Train Loss: 0.014911 - Val Loss: 0.000436 - R2: 0.8717
# Epoch 221/300 - Train Loss: 0.017561 - Val Loss: 0.000119 - R2: 0.9650
# Epoch 222/300 - Train Loss: 0.013056 - Val Loss: 0.000307 - R2: 0.9098
# Epoch 223/300 - Train Loss: 0.016235 - Val Loss: 0.000469 - R2: 0.8622
# Epoch 224/300 - Train Loss: 0.011503 - Val Loss: 0.000332 - R2: 0.9024
# Epoch 225/300 - Train Loss: 0.015872 - Val Loss: 0.000353 - R2: 0.8964
# Epoch 226/300 - Train Loss: 0.011245 - Val Loss: 0.000180 - R2: 0.9471
# Epoch 227/300 - Train Loss: 0.014337 - Val Loss: 0.000129 - R2: 0.9620
# Epoch 228/300 - Train Loss: 0.010731 - Val Loss: 0.000803 - R2: 0.7638
# Epoch 229/300 - Train Loss: 0.013446 - Val Loss: 0.000267 - R2: 0.9214
# Epoch 230/300 - Train Loss: 0.010554 - Val Loss: 0.000270 - R2: 0.9206
# Epoch 231/300 - Train Loss: 0.014064 - Val Loss: 0.000219 - R2: 0.9357
# Epoch 232/300 - Train Loss: 0.012247 - Val Loss: 0.000260 - R2: 0.9235
# Epoch 233/300 - Train Loss: 0.014036 - Val Loss: 0.000230 - R2: 0.9325
# Epoch 234/300 - Train Loss: 0.012195 - Val Loss: 0.000219 - R2: 0.9356
# Epoch 235/300 - Train Loss: 0.016612 - Val Loss: 0.000384 - R2: 0.8870
# Epoch 236/300 - Train Loss: 0.012578 - Val Loss: 0.000176 - R2: 0.9484
# Epoch 237/300 - Train Loss: 0.013410 - Val Loss: 0.000136 - R2: 0.9600
# Epoch 238/300 - Train Loss: 0.011123 - Val Loss: 0.001047 - R2: 0.6921
# Epoch 239/300 - Train Loss: 0.012992 - Val Loss: 0.001328 - R2: 0.6096
# Epoch 240/300 - Train Loss: 0.010793 - Val Loss: 0.000088 - R2: 0.9742
# Epoch 241/300 - Train Loss: 0.014924 - Val Loss: 0.000193 - R2: 0.9432
# Epoch 242/300 - Train Loss: 0.010364 - Val Loss: 0.001359 - R2: 0.6006
# Epoch 243/300 - Train Loss: 0.015299 - Val Loss: 0.000112 - R2: 0.9672
# Epoch 244/300 - Train Loss: 0.012766 - Val Loss: 0.000828 - R2: 0.7565
# Epoch 245/300 - Train Loss: 0.017217 - Val Loss: 0.000292 - R2: 0.9141
# Epoch 246/300 - Train Loss: 0.014198 - Val Loss: 0.000367 - R2: 0.8921
# Epoch 247/300 - Train Loss: 0.020060 - Val Loss: 0.000337 - R2: 0.9011
# Epoch 248/300 - Train Loss: 0.013069 - Val Loss: 0.000202 - R2: 0.9407
# Epoch 249/300 - Train Loss: 0.016876 - Val Loss: 0.001051 - R2: 0.6910
# Epoch 250/300 - Train Loss: 0.012454 - Val Loss: 0.000142 - R2: 0.9582
# Epoch 251/300 - Train Loss: 0.014796 - Val Loss: 0.000064 - R2: 0.9811
# Epoch 252/300 - Train Loss: 0.010936 - Val Loss: 0.000586 - R2: 0.8278
# Epoch 253/300 - Train Loss: 0.014338 - Val Loss: 0.000101 - R2: 0.9703
# Epoch 254/300 - Train Loss: 0.010611 - Val Loss: 0.000412 - R2: 0.8789
# Epoch 255/300 - Train Loss: 0.013177 - Val Loss: 0.000256 - R2: 0.9248
# Epoch 256/300 - Train Loss: 0.010444 - Val Loss: 0.000864 - R2: 0.7459
# Epoch 257/300 - Train Loss: 0.013506 - Val Loss: 0.000258 - R2: 0.9240
# Epoch 258/300 - Train Loss: 0.011981 - Val Loss: 0.000170 - R2: 0.9502
# Epoch 259/300 - Train Loss: 0.014697 - Val Loss: 0.000828 - R2: 0.7566
# Epoch 260/300 - Train Loss: 0.010658 - Val Loss: 0.000081 - R2: 0.9761
# Epoch 261/300 - Train Loss: 0.012318 - Val Loss: 0.000103 - R2: 0.9696
# Epoch 262/300 - Train Loss: 0.009404 - Val Loss: 0.000064 - R2: 0.9812
# Epoch 263/300 - Train Loss: 0.012324 - Val Loss: 0.000587 - R2: 0.8274
# Epoch 264/300 - Train Loss: 0.008784 - Val Loss: 0.000428 - R2: 0.8742
# Epoch 265/300 - Train Loss: 0.011367 - Val Loss: 0.000076 - R2: 0.9777
# Epoch 266/300 - Train Loss: 0.010441 - Val Loss: 0.000046 - R2: 0.9864
# Epoch 267/300 - Train Loss: 0.012670 - Val Loss: 0.000255 - R2: 0.9251
# Epoch 268/300 - Train Loss: 0.009357 - Val Loss: 0.000249 - R2: 0.9269
# Epoch 269/300 - Train Loss: 0.012852 - Val Loss: 0.000183 - R2: 0.9461
# Epoch 270/300 - Train Loss: 0.009726 - Val Loss: 0.000133 - R2: 0.9609
# Epoch 271/300 - Train Loss: 0.014218 - Val Loss: 0.000172 - R2: 0.9493
# Epoch 272/300 - Train Loss: 0.011501 - Val Loss: 0.000165 - R2: 0.9516
# Epoch 273/300 - Train Loss: 0.014651 - Val Loss: 0.000831 - R2: 0.7557
# Epoch 274/300 - Train Loss: 0.014849 - Val Loss: 0.000624 - R2: 0.8166
# Epoch 275/300 - Train Loss: 0.019967 - Val Loss: 0.001244 - R2: 0.6343
# Epoch 276/300 - Train Loss: 0.015030 - Val Loss: 0.001116 - R2: 0.6720
# Epoch 277/300 - Train Loss: 0.020173 - Val Loss: 0.000084 - R2: 0.9754
# Epoch 278/300 - Train Loss: 0.014465 - Val Loss: 0.000581 - R2: 0.8293
# Epoch 279/300 - Train Loss: 0.017878 - Val Loss: 0.000342 - R2: 0.8993
# Epoch 280/300 - Train Loss: 0.014372 - Val Loss: 0.000271 - R2: 0.9203
# Epoch 281/300 - Train Loss: 0.021065 - Val Loss: 0.000344 - R2: 0.8988
# Epoch 282/300 - Train Loss: 0.011231 - Val Loss: 0.000124 - R2: 0.9635
# Epoch 283/300 - Train Loss: 0.011615 - Val Loss: 0.000212 - R2: 0.9378
# Epoch 284/300 - Train Loss: 0.008809 - Val Loss: 0.000352 - R2: 0.8965
# Epoch 285/300 - Train Loss: 0.007985 - Val Loss: 0.000527 - R2: 0.8452
# Epoch 286/300 - Train Loss: 0.008305 - Val Loss: 0.000638 - R2: 0.8125
# Epoch 287/300 - Train Loss: 0.009068 - Val Loss: 0.001976 - R2: 0.4191
# Epoch 288/300 - Train Loss: 0.006174 - Val Loss: 0.000755 - R2: 0.7782
# Epoch 289/300 - Train Loss: 0.005949 - Val Loss: 0.000006 - R2: 0.9984
# Epoch 290/300 - Train Loss: 0.007183 - Val Loss: 0.000122 - R2: 0.9642
# Epoch 291/300 - Train Loss: 0.008546 - Val Loss: 0.000017 - R2: 0.9950
# Epoch 292/300 - Train Loss: 0.008541 - Val Loss: 0.000199 - R2: 0.9415
# Epoch 293/300 - Train Loss: 0.009735 - Val Loss: 0.000057 - R2: 0.9834
# Epoch 294/300 - Train Loss: 0.012947 - Val Loss: 0.000436 - R2: 0.8719
# Epoch 295/300 - Train Loss: 0.019099 - Val Loss: 0.000251 - R2: 0.9263
# Epoch 296/300 - Train Loss: 0.016065 - Val Loss: 0.002088 - R2: 0.3863
# Epoch 297/300 - Train Loss: 0.027159 - Val Loss: 0.000060 - R2: 0.9823
# Epoch 298/300 - Train Loss: 0.017095 - Val Loss: 0.000397 - R2: 0.8834
# Epoch 299/300 - Train Loss: 0.023533 - Val Loss: 0.000480 - R2: 0.8590
# Epoch 300/300 - Train Loss: 0.012870 - Val Loss: 0.000194 - R2: 0.9429

# %%
# Plot loss curve for lstm
plt.figure(figsize=(8, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid(True)
plt.savefig("figures/lstm-loss-curve.png", bbox_inches='tight')
plt.show()

# %%
# Evaluate LSTM model after training

best_model = LSTMModel(input_size=1, hidden_size=64, num_layers=2).to(device)
best_model.load_state_dict(torch.load(best_model_path))
best_model.to(device)
best_model.eval()

y_true_test, y_pred_test = [], []
with torch.no_grad():
    for x_batch, y_batch in test_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        output = best_model(x_batch)
        y_true_test.extend(y_batch.cpu().numpy())
        y_pred_test.extend(output.cpu().numpy())

y_true_test_inv = scaler_y.inverse_transform(np.array(y_true_test).reshape(-1, 1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(np.array(y_pred_test).reshape(-1, 1)).flatten()

lstm_rmse = np.sqrt(mean_squared_error(y_true_test_inv, y_pred_test_inv))
lstm_mae  = mean_absolute_error(y_true_test_inv, y_pred_test_inv)
lstm_mape = mean_absolute_percentage_error(y_true_test_inv, y_pred_test_inv)
lstm_r2   = r2_score(y_true_test_inv, y_pred_test_inv)

print(f"LSTM RMSE: {lstm_rmse:.4f}")
print(f"LSTM MAE : {lstm_mae:.4f}")
print(f"LSTM MAPE: {lstm_mape:.4f}")
print(f"LSTM R2  : {lstm_r2:.4f}")
# Out:
# LSTM RMSE: 0.3791
# LSTM MAE : 0.3510
# LSTM MAPE: 0.0038
# LSTM R2  : 0.9354

# %%
# Function to get predictions
def get_predictions(dataloader, model):
    preds, trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(device)
            output = model(x_batch)
            preds.extend(output.cpu().numpy())
            trues.extend(y_batch.cpu().numpy())
    return np.array(trues), np.array(preds)

# -------------------- Test Set Plot --------------------
y_true_test, y_pred_test = get_predictions(test_loader, best_model)
y_true_test_inv = scaler_y.inverse_transform(y_true_test.reshape(-1,1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(y_pred_test.reshape(-1,1)).flatten()

plt.figure(figsize=(8,5))
plt.plot(y_true_test_inv, label="Real", color="blue")
plt.plot(y_pred_test_inv, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.grid(alpha=0.3)
plt.savefig("figures/real-vs-predicted-test-set-lstm.png", bbox_inches='tight')
plt.show()

# -------------------- Full Dataset Plot (Train + Val + Test) --------------------
# Get predictions for all splits
y_true_train, y_pred_train = get_predictions(train_loader, best_model)
y_true_val, y_pred_val = get_predictions(val_loader, best_model)
y_true_test, y_pred_test = get_predictions(test_loader, best_model)

# Inverse transform
y_true_train_inv = scaler_y.inverse_transform(y_true_train.reshape(-1,1)).flatten()
y_pred_train_inv = scaler_y.inverse_transform(y_pred_train.reshape(-1,1)).flatten()
y_true_val_inv = scaler_y.inverse_transform(y_true_val.reshape(-1,1)).flatten()
y_pred_val_inv = scaler_y.inverse_transform(y_pred_val.reshape(-1,1)).flatten()
y_true_test_inv = scaler_y.inverse_transform(y_true_test.reshape(-1,1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(y_pred_test.reshape(-1,1)).flatten()

# Concatenate all
y_true_all = np.concatenate([y_true_train_inv, y_true_val_inv, y_true_test_inv])
y_pred_all = np.concatenate([y_pred_train_inv, y_pred_val_inv, y_pred_test_inv])

# Split indices
train_end = len(y_true_train_inv)
val_end = train_end + len(y_true_val_inv)

# Plot
plt.figure(figsize=(12,5))
plt.plot(y_true_all, label="Real", color="blue")
plt.plot(y_pred_all, label="Predicted", color="red", linestyle="--")

# Mark train/val/test splits
plt.axvline(x=train_end, color="green", linestyle=":", label="Train/Val Split")
plt.axvline(x=val_end, color="black", linestyle=":", label="Val/Test Split")

plt.title("Real vs Predicted - Full Dataset (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("figures/real-vs-predicted-full-dataset-lstm.png", bbox_inches='tight')
plt.show()

# %%
# Plot residual plot and distribution of residual plot for lstm model

y_true_test = np.array(y_true_test)
y_pred_test = np.array(y_pred_test)
residuals_test = y_true_test - y_pred_test

# Residual Plot
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-lstm.png", bbox_inches='tight')
plt.show()

#Distribution of Residuals
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, kde=True, bins=30, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution (LSTM)")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distributions-lstm.png", bbox_inches='tight')
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

# -------------------- Compute residuals --------------------
# Residuals on test set
residuals = y_true_test_inv - y_pred_test_inv

# -------------------- Plot ACF of Residuals --------------------
plt.figure(figsize=(12,4))
plot_acf(residuals, lags=40, ax=plt.gca())
plt.title("ACF of Residuals")
plt.show()

# -------------------- Plot PACF of Residuals --------------------
plt.figure(figsize=(12,4))
plot_pacf(residuals, lags=40, ax=plt.gca())
plt.title("PACF of Residuals")
plt.show()

# -------------------- Ljung-Box Test --------------------
# Null hypothesis: residuals are independently distributed
lb_test = acorr_ljungbox(residuals, lags=[10, 15, 20], return_df=True)

print("Ljung-Box test results for residuals:")
print(lb_test)
# Out:
# Ljung-Box test results for residuals:
#         lb_stat      lb_pvalue
# 10   877.086455  5.431315e-182
# 15  1110.086941  3.302043e-227
# 20  1251.282613  7.959417e-253

# %% [markdown]
# ## **Machine Learning Model 1: Random Forest**

# %%
# Prepare dataset for Random Forest

df_weekly = df_weekly.sort_values('Date').reset_index(drop=True)
series = df_weekly['Penetration'].values

def create_features(series, seq_length=64):
    X, y = [], []
    for i in range(seq_length, len(series)):
        lag_window = series[i-seq_length:i].copy()
        diff_window = np.diff(lag_window, prepend=lag_window[0])
        feature_row = np.concatenate([lag_window, diff_window])
        X.append(feature_row)
        y.append(series[i])
    return np.array(X), np.array(y)

seq_length = 64
X, y = create_features(series, seq_length)

time_index = np.arange(len(series))[seq_length:].reshape(-1,1)
X = np.hstack([X, time_index])

# Train/test split (first 80% train, last 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Scale features
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1,1)).flatten()
y_test_scaled = scaler_y.transform(y_test.reshape(-1,1)).flatten()

# %%
# Train Random Forest
rf_model = RandomForestRegressor(n_estimators=300, max_depth=15, random_state=42)
rf_model.fit(X_train_scaled, y_train_scaled)
# Out:
# RandomForestRegressor(max_depth=15, n_estimators=300, random_state=42)

# %%
# Predictions
y_pred_train_scaled = rf_model.predict(X_train_scaled)
y_pred_test_scaled = rf_model.predict(X_test_scaled)

y_pred_train = scaler_y.inverse_transform(y_pred_train_scaled.reshape(-1,1)).flatten()
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled.reshape(-1,1)).flatten()

# Metrics
rf_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
rf_mae  = mean_absolute_error(y_test, y_pred_test)
rf_mape = mean_absolute_percentage_error(y_test, y_pred_test)
rf_r2   = r2_score(y_test, y_pred_test)

print(f"Random Forest RMSE: {rf_rmse:.4f}")
print(f"Random Forest MAE : {rf_mae:.4f}")
print(f"Random Forest MAPE: {rf_mape:.4f}")
print(f"Random Forest R2  : {rf_r2:.4f}")
# Out:
# Random Forest RMSE: 3.8157
# Random Forest MAE : 3.3479
# Random Forest MAPE: 0.0361
# Random Forest R2  : -4.1146

# %%
# Function to get predictions
def get_predictions(dataloader, model):
    preds, trues = [], []
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(device)
            output = model(x_batch)
            preds.extend(output.cpu().numpy())
            trues.extend(y_batch.cpu().numpy())
    return np.array(trues), np.array(preds)

# -------------------- Test Set Plot --------------------
y_true_test, y_pred_test = get_predictions(test_loader, best_model)
y_true_test_inv = scaler_y.inverse_transform(y_true_test.reshape(-1,1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(y_pred_test.reshape(-1,1)).flatten()

plt.figure(figsize=(8,5))
plt.plot(y_true_test_inv, label="Real", color="blue")
plt.plot(y_pred_test_inv, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.grid(alpha=0.3)
plt.savefig("figures/real-vs-predicted-test-set-lstm.png", bbox_inches='tight')
plt.show()

# -------------------- Full Dataset Plot (Train + Val + Test) --------------------
# Get predictions for all splits
y_true_train, y_pred_train = get_predictions(train_loader, best_model)
y_true_val, y_pred_val = get_predictions(val_loader, best_model)
y_true_test, y_pred_test = get_predictions(test_loader, best_model)

# Inverse transform
y_true_train_inv = scaler_y.inverse_transform(y_true_train.reshape(-1,1)).flatten()
y_pred_train_inv = scaler_y.inverse_transform(y_pred_train.reshape(-1,1)).flatten()
y_true_val_inv = scaler_y.inverse_transform(y_true_val.reshape(-1,1)).flatten()
y_pred_val_inv = scaler_y.inverse_transform(y_pred_val.reshape(-1,1)).flatten()
y_true_test_inv = scaler_y.inverse_transform(y_true_test.reshape(-1,1)).flatten()
y_pred_test_inv = scaler_y.inverse_transform(y_pred_test.reshape(-1,1)).flatten()

# Concatenate all
y_true_all = np.concatenate([y_true_train_inv, y_true_val_inv, y_true_test_inv])
y_pred_all = np.concatenate([y_pred_train_inv, y_pred_val_inv, y_pred_test_inv])

# Split indices
train_end = len(y_true_train_inv)
val_end = train_end + len(y_true_val_inv)

# Plot
plt.figure(figsize=(12,5))
plt.plot(y_true_all, label="Real", color="blue")
plt.plot(y_pred_all, label="Predicted", color="red", linestyle="--")

# Mark train/val/test splits
plt.axvline(x=train_end, color="green", linestyle=":", label="Train/Val Split")
plt.axvline(x=val_end, color="black", linestyle=":", label="Val/Test Split")

plt.title("Real vs Predicted - Full Dataset (LSTM)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("figures/real-vs-predicted-full-dataset-lstm.png", bbox_inches='tight')
plt.show()

# %%
#Residual Plot (Test Set)
residuals_test = y_true_test - y_pred_test
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot (Random Forest)")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-rf.png", bbox_inches='tight')
plt.show()

#Residual Distribution (Test Set)
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, kde=True, bins=30, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution (Random Forest)")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distributions-rf.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Machine Learning Model 2: SARIMAX**

# %%
#Prepare series
df_weekly = df_weekly.sort_values('Date').reset_index(drop=True)
series = df_weekly['Penetration']

#Train/Test Split
train_size = int(len(series) * 0.8)
train_series = series[:train_size]
test_series = series[train_size:]

# %%
import itertools
import warnings
from statsmodels.tsa.statespace.sarimax import SARIMAX
from tqdm import tqdm

warnings.filterwarnings("ignore") 

# -------------------- parameter ranges --------------------
p = q = range(0, 3)          # AR & MA terms
d = [1]                       # differencing usually 1
P = Q = range(0, 2)           # Seasonal AR & MA terms
D = [1]                        # seasonal differencing
s = 52                         # Weekly seasonality for yearly data

# Generate all combinations
pdq = list(itertools.product(p, d, q))
seasonal_pdq = list(itertools.product(P, D, Q))

# -------------------- Grid Search --------------------
best_aic = float("inf")
best_order = None
best_seasonal_order = None

for order in tqdm(pdq, desc="SARIMAX p,d,q grid"):
    for seasonal_order in seasonal_pdq:
        try:
            model = SARIMAX(
                train_series,
                order=order,
                seasonal_order=(seasonal_order[0], seasonal_order[1], seasonal_order[2], s),
                enforce_stationarity=False,
                enforce_invertibility=False
            )
            results = model.fit(disp=False)
            
            if results.aic < best_aic:
                best_aic = results.aic
                best_order = order
                best_seasonal_order = seasonal_order
        except:
            continue

# -------------------- Print best parameters --------------------
print("Best SARIMAX parameters based on AIC:")
print(f"Order (p,d,q): {best_order}")
print(f"Seasonal order (P,D,Q,s): {best_seasonal_order + (s,)}")
print(f"Best AIC: {best_aic:.4f}")
# Out:
# SARIMAX p,d,q grid: 100%|███████████████████████████████████████████████████████████████| 9/9 [49:33<00:00, 330.38s/it]
# Best SARIMAX parameters based on AIC:
# Order (p,d,q): (2, 1, 2)
# Seasonal order (P,D,Q,s): (0, 1, 1, 52)
# Best AIC: -9496.1081
#
# Final model fitted.

# %%
sarimax_model = SARIMAX(
    train_series,
    order=(2,1,2),
    seasonal_order=(0,1,1,52),
    enforce_stationarity=False,
    enforce_invertibility=False
)
sarimax_result = sarimax_model.fit(disp=False)

# %%
# --------- Predictions ---------
train_pred = sarimax_result.predict(start=0, end=len(train_series)-1, dynamic=False)

# Forecast test
test_pred = sarimax_result.forecast(steps=len(test_series))

# --------- Metrics ---------
sarimax_rmse = np.sqrt(mean_squared_error(test_series, test_pred))
sarimax_mae  = mean_absolute_error(test_series, test_pred)
sarimax_mape = mean_absolute_percentage_error(test_series, test_pred)
sarimax_r2   = r2_score(test_series, test_pred)

print(f"SARIMAX RMSE: {sarimax_rmse:.4f}")
print(f"SARIMAX MAE : {sarimax_mae:.4f}")
print(f"SARIMAX MAPE: {sarimax_mape:.4f}")
print(f"SARIMAX R2  : {sarimax_r2:.4f}")
# Out:
# SARIMAX RMSE: 1.0922
# SARIMAX MAE : 0.8036
# SARIMAX MAPE: 0.0087
# SARIMAX R2  : 0.6279

# %%
#Plot Test Set(Actual vs Predicted) 
plt.figure(figsize=(8,5))
plt.plot(test_series.values, label="Real", color="blue")
plt.plot(test_pred.values, label="Predicted", color="red", linestyle="--")
plt.title("Real vs Predicted - Test Set (SARIMAX)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-test-set-sarimax.png", bbox_inches='tight')

plt.show()

# --------- Plot Whole Series ---------
all_real = np.concatenate([train_series.values, test_series.values])
all_pred = np.concatenate([train_pred.values, test_pred.values])

plt.figure(figsize=(8,5))
plt.plot(range(len(all_real)), all_real, label="Real", color="blue")
plt.plot(range(len(all_pred)), all_pred, label="Predicted", color="red", linestyle="--")
plt.axvline(x=len(train_series), color="black", linestyle=":", label="Train/Test Split")
plt.title("Real vs Predicted - Whole Datast (SARIMAX)")
plt.xlabel("Time Steps")
plt.ylabel("Penetration")
plt.legend()
plt.savefig("figures/real-vs-predicted-whole-dataset-sarimax.png", bbox_inches='tight')
plt.show()

# %%
#Residual Plot
residuals_test = test_series.values - test_pred.values
plt.figure(figsize=(8,5))
plt.scatter(range(len(residuals_test)), residuals_test, alpha=0.7)
plt.axhline(0, color="red", linestyle="--")
plt.title("Residual Plot SARIMAX")
plt.xlabel("Time Steps")
plt.ylabel("Residuals")
plt.savefig("figures/residuals-sarimax.png", bbox_inches='tight')
plt.show()

#Residual Distribution
plt.figure(figsize=(8,5))
sns.histplot(residuals_test, bins=30, kde=True, color="purple")
plt.axvline(0, color="red", linestyle="--")
plt.title("Residual Distribution SARIMAX")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.savefig("figures/residual-distribution-sarimax.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **Comparison of All three models**

# %%
#Metrics for each model
data = {
    "Model": ["LSTM", "SARIMAX", "Random Forest"],
    "Type":  ["Deep Learning", "Machine Learning", "Machine Learning"],
    "RMSE":  [lstm_rmse, sarimax_rmse, rf_rmse],
    "MAE":   [lstm_mae, sarimax_mae, rf_mae],
    "MAPE":  [lstm_mape, sarimax_mape, rf_mape],
    "R2":    [lstm_r2, sarimax_r2, rf_r2]
}

df_metrics = pd.DataFrame(data)

#Display the table
print("Comparison of Models:")
df_metrics
# Out:
# Comparison of Models:
#            Model              Type      RMSE       MAE      MAPE        R2
# 0           LSTM     Deep Learning  0.379074  0.350997  0.003757  0.935364
# 1        SARIMAX  Machine Learning  1.092202  0.803581  0.008660  0.627872
# 2  Random Forest  Machine Learning  3.815748  3.347931  0.036134 -4.114641

# %%
metrics = ["RMSE", "MAE", "MAPE", "R2"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]
bar_width = 0.5 

for i, metric in enumerate(metrics):
    plt.figure(figsize=(4,4))
    values = df_metrics[metric].values
    plt.bar(df_metrics["Model"], values, color=colors, width=bar_width)
    plt.title(f"Comparison of {metric} Across Models")
    plt.ylabel(metric)
    plt.grid(alpha=0.3, axis='y')
    
    plt.savefig(f"figures/{metric}_comparison.png", bbox_inches='tight')
    
    plt.show()
